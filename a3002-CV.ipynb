# %%
import json
import pandas as pd       
import os
import nltk
from nltk.corpus import stopwords

# Open Trining File
os.chdir("/temp/DocumentCorpus/ECHR/echr_dataset-master/echr_dataset-master/document_crawler/IN/")
train = pd.read_csv("TRAIN_classifiedFULL_NOADMISS.tsv", header=0, delimiter="^", quoting=3)
test  = pd.read_csv("TEST_NOclassifiedFULL_NOADMISS.tsv", header=0, delimiter="^", quoting=3)

os.chdir("/temp/DocumentCorpus/ECHR/echr_dataset-master/echr_dataset-master/document_crawler/OUT/AV3/CV/")

train.shape
test.shape

train.columns.values

from bs4 import BeautifulSoup   
import re

from nltk.stem.porter import *
from nltk import WordNetLemmatizer

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    
    # 5a. Remove extra Stop words
    moreStopwords = ["b","full","value","file","period","months","additional","basis","street","respect","cases","application","amount","since","costs","address","well","days","series","c","particular","purposes","purpose","proceedings","proceeding","h","able","ba","country","held","board","first","second","final","judge","non","statement","documents","many","notes","note","j","considered","aw","echr","whether","language","ill","time","taken","kh","rovd","must","set","within","p","mr","mrs","provided","sher","one","new","route","routes","three","would","previously","shall","en","k","g","applicants","eur","date","might","paragraph","u","kd","could","made","company","see","public","parking","statements","article","government","business","information","therefore","right","also","applicant","court","act","state","security","section","hearing","v","service","case","law","person","courts","regional","january","february","march","april","may","june","july","august","september","october","november","december"]
    more_meaningful_words = [token for token in meaningful_words if token not in moreStopwords]
    
    #
    # 6. Stemmer
    #stemmed=[]
    #stemmer = PorterStemmer()
    #for word in more_meaningful_words:
    #    stemmed.append(stemmer.stem(word))
        
    #
    # 7. Lemmatizer
    Lemmatized=[]
    Lemmatizer = WordNetLemmatizer()
    for word in more_meaningful_words:
        Lemmatized.append(Lemmatizer.lemmatize(word))
        
    #
    # 8. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( Lemmatized ))  
    #return( " ".join( stemmed ))  
    #return( " ".join( more_meaningful_words ))  
    #return( " ".join( meaningful_words ))   
    
# Get the number of cases based on the dataframe column size

num_reviews = train["sentences"].size

# Initialize an empty list to hold the clean cases
clean_train_sentences = []

# Loop over each case 
for i in xrange( 0, num_reviews ):
    # If the index is evenly divisible by 100, print a message
    if( (i+1)%50 == 0 ):
        print "CASE %d of %d\n" % ( i+1, num_reviews )                                                                    
    clean_train_sentences.append( review_to_words( train["sentences"][i] ))
# Out:
# C:\Users\danny\AppData\Local\Enthought\Canopy\User\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# CASE 50 of 4000
#
# CASE 100 of 4000
#
# CASE 150 of 4000
#
# CASE 200 of 4000
#
# CASE 250 of 4000
#
# CASE 300 of 4000
#
# CASE 350 of 4000
#
# CASE 400 of 4000
#
# CASE 450 of 4000
#
# CASE 500 of 4000
#
# CASE 550 of 4000
#
# CASE 600 of 4000
#
# CASE 650 of 4000
#
# CASE 700 of 4000
#
# CASE 750 of 4000
#
# CASE 800 of 4000
#
# CASE 850 of 4000
#
# CASE 900 of 4000
#
# CASE 950 of 4000
#
# CASE 1000 of 4000
#
# CASE 1050 of 4000
#
# CASE 1100 of 4000
#
# CASE 1150 of 4000
#
# CASE 1200 of 4000
#
# CASE 1250 of 4000
#
# CASE 1300 of 4000
#
# CASE 1350 of 4000
#
# CASE 1400 of 4000
#
# CASE 1450 of 4000
#
# CASE 1500 of 4000
#
# CASE 1550 of 4000
#
# CASE 1600 of 4000
#
# CASE 1650 of 4000
#
# CASE 1700 of 4000
#
# CASE 1750 of 4000
#
# CASE 1800 of 4000
#
# CASE 1850 of 4000
#
# CASE 1900 of 4000
#
# CASE 1950 of 4000
#
# CASE 2000 of 4000
#
# CASE 2050 of 4000
#
# CASE 2100 of 4000
#
# CASE 2150 of 4000
#
# CASE 2200 of 4000
#
# CASE 2250 of 4000
#
# CASE 2300 of 4000
#
# CASE 2350 of 4000
#
# CASE 2400 of 4000
#
# CASE 2450 of 4000
#
# CASE 2500 of 4000
#
# CASE 2550 of 4000
#
# CASE 2600 of 4000
#
# CASE 2650 of 4000
#
# CASE 2700 of 4000
#
# CASE 2750 of 4000
#
# CASE 2800 of 4000
#
# CASE 2850 of 4000
#
# CASE 2900 of 4000
#
# CASE 2950 of 4000
#
# CASE 3000 of 4000
#
# CASE 3050 of 4000
#
# CASE 3100 of 4000
#
# CASE 3150 of 4000
#
# CASE 3200 of 4000
#
# CASE 3250 of 4000
#
# CASE 3300 of 4000
#
# CASE 3350 of 4000
#
# CASE 3400 of 4000
#
# CASE 3450 of 4000
#
# CASE 3500 of 4000
#
# CASE 3550 of 4000
#
# CASE 3600 of 4000
#
# CASE 3650 of 4000
#
# CASE 3700 of 4000
#
# CASE 3750 of 4000
#
# CASE 3800 of 4000
#
# CASE 3850 of 4000
#
# CASE 3900 of 4000
#
# CASE 3950 of 4000
#
# CASE 4000 of 4000

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  

vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 


# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features=[]
train_data_features = vectorizer.fit_transform(clean_train_sentences)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()

print(train_data_features.shape)

vocab = vectorizer.get_feature_names()
print(vocab)


import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
    
print "Training the random forest..."
#from sklearn.ensemble import RandomForestClassifier
#
## Initialize a Random Forest classifier with 100 trees
#forest = RandomForestClassifier(n_estimators = 100) 
#
## Fit the forest to the training set, using the bag of words as 
## features and the sentiment labels as the response variable
##
## This may take a few minutes to run
#forest = forest.fit( train_data_features, train["AV3"] )    

from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

grid_values = {} #{'C':[30]} # Decide which settings you want for the grid search. 

model_LR = GridSearchCV(RandomForestClassifier(n_estimators = 100), 
                        grid_values, 
                        scoring = 'roc_auc', cv = 20) 

# Try to set the scoring on what the contest is asking for. 
# The contest says scoring is for area under the ROC curve, so use this.
                            
model_LR.fit(train_data_features, train["AV3"] ) # Fit the model.

model_LR.grid_scores_
# Out:
# (4000L, 5000L)
# [u'abandoned', u'abayev', u'abdomen', u'abdominal', u'abducted', u'abduction', u'abductor', u'abdul', u'abetting', u'ability', u'abolished', u'abrasion', u'abroad', u'abscond', u'absconded', u'absconding', u'absence', u'absent', u'absentia', u'absolute', u'absolutely', u'abuse', u'abused', u'abusive', u'academy', u'acar', u'acceded', u'accept', u'acceptable', u'accepted', u'accepting', u'accepts', u'access', u'accessible', u'accident', u'accommodate', u'accommodated', u'accommodation', u'accompanied', u'accompanying', u'accomplice', u'accordance', u'according', u'accordingly', u'account', u'accounting', u'accuracy', u'accurate', u'accusation', u'accused', u'accusing', u'achieve', u'achieved', u'achkhoy', u'acknowledged', u'acknowledgement', u'acknowledging', u'acknowledgment', u'acquaintance', u'acquainted', u'acquire', u'acquired', u'acquiring', u'acquisition', u'acquittal', u'acquitted', u'across', u'act', u'acted', u'acting', u'action', u'active', u'actively', u'activist', u'activity', u'actual', u'actually', u'acute', u'ad', u'adam', u'adapted', u'add', u'added', u'addict', u'addiction', u'adding', u'addition', u'additionally', u'address', u'addressed', u'addressee', u'addressing', u'adduce', u'adduced', u'adequacy', u'adequate', u'adequately', u'adjacent', u'adjourn', u'adjourned', u'adjournment', u'adjudication', u'adjustment', u'administered', u'administering', u'administration', u'administrative', u'administrator', u'admissibility', u'admissible', u'admission', u'admit', u'admitted', u'adopt', u'adopted', u'adopting', u'adoption', u'adoptive', u'adult', u'advance', u'advanced', u'advantage', u'adversarial', u'adverse', u'adversely', u'advice', u'advised', u'adviser', u'advisory', u'advocate', u'affair', u'affect', u'affected', u'affecting', u'affidavit', u'affiliation', u'affirmed', u'afford', u'afforded', u'afghan', u'afghanistan', u'aforementioned', u'afraid', u'afternoon', u'afterwards', u'age', u'aged', u'agency', u'agent', u'aggravated', u'aggravating', u'aggressive', u'aggrieved', u'ago', u'agree', u'agreed', u'agreement', u'agricultural', u'agriculture', u'aid', u'aiding', u'aim', u'aimed', u'air', u'aircraft', u'airport', u'ak', u'akayeva', u'akhmadova', u'akhmed', u'al', u'albania', u'albanian', u'albeit', u'albuquerque', u'alcohol', u'alcoholic', u'ale', u'aleksandr', u'alekseyev', u'alexandre', u'ali', u'alia', u'alien', u'alignment', u'alive', u'aliyev', u'allegation', u'alleged', u'allegedly', u'alleges', u'alleging', u'allocated', u'allocation', u'allow', u'allowance', u'allowed', u'allowing', u'allows', u'almost', u'alone', u'along', u'already', u'alter', u'altercation', u'altered', u'alternative', u'alternatively', u'although', u'alvina', u'always', u'ambassador', u'ambulance', u'amenable', u'amend', u'amended', u'amending', u'amendment', u'america', u'american', u'ammunition', u'amnesty', u'among', u'amongst', u'amount', u'amounted', u'amounting', u'ana', u'analysed', u'analysis', u'anatoly', u'andijan', u'andr', u'anew', u'angelika', u'animal', u'ankara', u'ankle', u'ann', u'annex', u'announced', u'announcement', u'annual', u'annul', u'annulled', u'annulment', u'anonymous', u'another', u'answer', u'answered', u'anti', u'anticipated', u'antiretroviral', u'antoanella', u'anvar', u'anxiety', u'anyone', u'anything', u'apart', u'apartment', u'apc', u'apelacyjny', u'apology', u'appalling', u'apparent', u'apparently', u'appeal', u'appealed', u'appealing', u'appear', u'appearance', u'appeared', u'appears', u'appellant', u'appellate', u'appended', u'appendix', u'applicability', u'applicable', u'application', u'applied', u'applies', u'apply', u'applying', u'appoint', u'appointed', u'appointment', u'apprehended', u'apprehension', u'approach', u'approached', u'appropriate', u'approval', u'approve', u'approved', u'approximately', u'apti', u'ar', u'arac', u'arbitrarily', u'arbitrary', u'arbitration', u'arc', u'archive', u'area', u'aresztowanie', u'arguable', u'argue', u'argued', u'arguing', u'argument', u'argun', u ...
# 149 abandoned
# 90 abayev
# 101 abdomen
# 99 abdominal
# 924 abducted
# 3192 abduction
# 611 abductor
# 175 abdul
# 93 abetting
# 384 ability
# 117 abolished
# 307 abrasion
# 537 abroad
# 871 abscond
# 107 absconded
# 418 absconding
# 2875 absence
# 309 absent
# 197 absentia
# 234 absolute
# 313 absolutely
# 1772 abuse
# 275 abused
# 155 abusive
# 150 academy
# 116 acar
# 206 acceded
# 740 accept
# 223 acceptable
# 1505 accepted
# 136 accepting
# 123 accepts
# 4269 access
# 211 accessible
# 848 accident
# 163 accommodate
# 282 accommodated
# 704 accommodation
# 791 accompanied
# 132 accompanying
# 315 accomplice
# 5827 accordance
# 11027 according
# 1747 accordingly
# 6739 account
# 100 accounting
# 155 accuracy
# 125 accurate
# 489 accusation
# 5569 accused
# 173 accusing
# 159 achieve
# 203 achieved
# 254 achkhoy
# 825 acknowledged
# 103 acknowledgement
# 90 acknowledging
# 149 acknowledgment
# 227 acquaintance
# 93 acquainted
# 184 acquire
# 675 acquired
# 109 acquiring
# 221 acquisition
# 236 acquittal
# 641 acquitted
# 230 across
# 3032 act
# 881 acted
# 1546 acting
# 7846 action
# 509 active
# 202 actively
# 251 activist
# 4341 activity
# 522 actual
# 499 actually
# 287 acute
# 671 ad
# 186 adam
# 94 adapted
# 178 add
# 1068 added
# 131 addict
# 141 addiction
# 141 adding
# 2270 addition
# 209 additionally
# 189 address
# 830 addressed
# 97 addressee
# 135 addressing
# 123 adduce
# 261 adduced
# 131 adequacy
# 1592 adequate
# 270 adequately
# 166 adjacent
# 163 adjourn
# 1598 adjourned
# 325 adjournment
# 140 adjudication
# 134 adjustment
# 286 administered
# 110 administering
# 3257 administration
# 8776 administrative
# 200 administrator
# 3639 admissibility
# 300 admissible
# 1026 admission
# 320 admit
# 1557 admitted
# 413 adopt
# 6499 adopted
# 107 adopting
# 1418 adoption
# 302 adoptive
# 375 adult
# 332 advance
# 236 advanced
# 139 advantage
# 177 adversarial
# 191 adverse
# 91 adversely
# 297 advice
# 465 advised
# 209 adviser
# 94 advisory
# 580 advocate
# 1960 affair
# 402 affect
# 677 affected
# 220 affecting
# 124 affidavit
# 104 affiliation
# 108 affirmed
# 168 afford
# 447 afforded
# 260 afghan
# 650 afghanistan
# 438 aforementioned
# 210 afraid
# 160 afternoon
# 425 afterwards
# 1482 age
# 145 aged
# 1902 agency
# 4922 agent
# 871 aggravated
# 124 aggravating
# 290 aggressive
# 155 aggrieved
# 98 ago
# 299 agree
# 1274 agreed
# 2356 agreement
# 302 agricultural
# 148 agriculture
# 1980 aid
# 105 aiding
# 1099 aim
# 785 aimed
# 862 air
# 313 aircraft
# 465 airport
# 131 ak
# 93 akayeva
# 137 akhmadova
# 197 akhmed
# 620 al
# 220 albania
# 157 albanian
# 103 albeit
# 311 albuquerque
# 423 alcohol
# 108 alcoholic
# 171 ale
# 143 aleksandr
# 116 alekseyev
# 359 alexandre
# 623 ali
# 3889 alia
# 1132 alien
# 135 alignment
# 127 alive
# 241 aliyev
# 4175 allegation
# 12145 alleged
# 2105 allegedly
# 151 alleges
# 807 alleging
# 481 allocated
# 167 allocation
# 1273 allow
# 605 allowance
# 3609 allowed
# 475 allowing
# 203 allows
# 578 almost
# 814 alone
# 565 along
# 2818 already
# 112 alter
# 88 altercation
# 95 altered
# 598 alternative
# 107 alternatively
# 2166 although
# 281 alvina
# 651 always
# 127 ambassador
# 540 ambulance
# 180 amenable
# 222 amend
# 1629 amended
# 134 amending
# 1531 amendment
# 147 america
# 128 american
# 169 ammunition
# 486 amnesty
# 1697 among
# 254 amongst
# 477 amount
# 839 amounted
# 245 amounting
# 94 ana
# 202 analysed
# 511 analysis
# 664 anatoly
# 96 andijan
# 891 andr
# 92 anew
# 349 angelika
# 100 animal
# 414 ankara
# 90 ankle
# 261 ann
# 407 annex
# 276 announced
# 104 announcement
# 313 annual
# 151 annul
# 396 annulled
# 449 annulment
# 144 anonymous
# 5923 another
# 631 answer
# 259 answered
# 860 anti
# 125 anticipated
# 106 antiretroviral
# 104 antoanella
# 97 anvar
# 111 anxiety
# 709 anyone
# 505 anything
# 380 apart
# 1123 apartment
# 917 apc
# 122 apelacyjny
# 105 apology
# 180 appalling
# 280 apparent
# 745 apparently
# 26964 appeal
# 4394 appealed
# 89 appealing
# 2331 appear
# 427 appearance
# 902 appeared
# 2210 appears
# 800 appellant
# 1042 appellate
# 121 appended
# 226 appendix
# 144 applicability
# 2170 applicable
# 2931 application
# 3745 applied
# 410 applies
# 2377 apply
# 760 applying
# 477 appoint
# 1935 appointed
# 472 appointment
# 483 apprehended
# 239 apprehension
# 533 approach
# 410 approached
# 2613 appropriate
# 446 approval
# 116 approve
# 691 approved
# 1546 approximately
# 181 apti
# 144 ar
# 254 arac
# 164 arbitrarily
# 550 arbitrary
# 207 arbitration
# 93 arc
# 149 archive
# 2923 area
# 122 aresztowanie
# 108 arguable
# 135 argue
# 3370 argued
# 854 arguing
# 3936 argument
# 100 argun
# 340 arise
# 89 arisen
# 113 arises
# 401 arising
# 1101 arm
# 3130 armed
# 523 armenia
# 262 armenian
# 173 armoured
# 525 army
# 133 arose
# 1580 around
# 173 arrange
# 192 arranged
# 818 arrangement
# 398 arrears
# 6523 arrest
# 3861 arrested
# 184 arresting
# 916 arrival
# 1939 arrived
# 114 arriving
# 300 art
# 4595 article
# 219 artificial
# 93 artur
# 146 ascertain
# 100 ascertained
# 718 aside
# 529 ask
# 5099 asked
# 772 asking
# 422 aslan
# 169 aslanbek
# 634 aspect
# 575 ass
# 545 assault
# 211 assaulted
# 1278 assembly
# 334 asserted
# 364 assertion
# 772 assessed
# 559 assessing
# 2938 assessment
# 783 asset
# 101 assign
# 889 assigned
# 141 assignment
# 386 assist
# 3576 assistance
# 436 assistant
# 484 assisted
# 94 assisting
# 843 assize
# 110 associate
# 276 associated
# 2027 association
# 137 assume
# 281 assumed
# 156 assuming
# 223 assumption
# 614 assurance
# 92 assured
# 101 astrakhan
# 3003 asylum
# 121 atagi
# 873 attached
# 145 attachment
# 1304 attack
# 339 attacked
# 1191 attempt
# 1267 attempted
# 210 attempting
# 1009 attend
# 389 attendance
# 592 attended
# 229 attending
# 887 attention
# 245 attesting
# 376 attitude
# 1625 attorney
# 224 attributable
# 244 attributed
# 240 auction
# 232 audio
# 189 audit
# 801 austria
# 425 austrian
# 119 authenticity
# 318 author
# 918 authorisation
# 240 authorise
# 1772 authorised
# 330 authorising
# 20727 authority
# 273 automatic
# 204 automatically
# 151 autonomous
# 242 autopsy
# 126 autumn
# 99 av
# 425 avail
# 117 availability
# 2877 available
# 215 avenue
# 357 average
# 109 aviation
# 596 avoid
# 112 avoided
# 102 avoiding
# 95 awaiting
# 922 award
# 1795 awarded
# 188 awarding
# 994 aware
# 102 awareness
# 1778 away
# 97 ay
# 904 azerbaijan
# 357 azerbaijani
# 90 baby
# 126 bac
# 2772 back
# 913 background
# 274 bad
# 350 bag
# 762 bail
# 1883 bailiff
# 130 bak
# 458 baku
# 278 balance
# 102 balcony
# 110 ballistic
# 165 ballot
# 386 ban
# 1365 bank
# 502 bankruptcy
# 239 banned
# 1059 bar
# 442 barred
# 240 barreto
# 95 barrier
# 346 base
# 3740 based
# 181 basement
# 182 bashir
# 1014 basic
# 108 bathroom
# 127 battalion
# 91 battery
# 432 bear
# 519 bearing
# 374 beat
# 1439 beaten
# 921 beating
# 1909 became
# 4744 become
# 229 becomes
# 180 becoming
# 1263 bed
# 342 bedding
# 800 began
# 128 begin
# 590 beginning
# 143 begun
# 1229 behalf
# 125 behaved
# 1232 behaviour
# 578 behind
# 335 belarus
# 88 belarusian
# 108 belated
# 202 belgium
# 213 belgrade
# 503 belief
# 726 believe
# 274 believed
# 146 believing
# 165 belong
# 449 belonged
# 883 belonging
# 576 bench
# 106 beneficiary
# 1625 benefit
# 105 benefited
# 359 berger
# 153 berlin
# 629 berro
# 140 besides
# 116 beslan
# 663 best
# 338 better
# 130 beyo
# 874 beyond
# 106 bez
# 504 bgn
# 199 bi
# 120 bia
# 443 bianku
# 263 bias
# 151 biased
# 120 bilateral
# 956 bill
# 720 binding
# 309 biological
# 611 birth
# 435 bj
# 224 black
# 91 blade
# 183 blanket
# 187 bleeding
# 100 blindfolded
# 364 block
# 195 blocked
# 118 blocking
# 1280 blood
# 430 blow
# 100 blue
# 267 blunt
# 470 bo
# 929 bodily
# 5077 body
# 154 bolotnaya
# 169 bomb
# 107 bona
# 197 bond
# 181 bone
# 348 bonello
# 495 book
# 795 border
# 175 bore
# 5595 born
# 139 borne
# 152 borrego
# 622 bosnia
# 109 bottle
# 309 bought
# 518 bound
# 134 boundary
# 144 box
# 440 boy
# 128 br
# 104 bra
# 265 brain
# 568 branch
# 122 branko
# 214 bratislava
# 542 bratza
# 3594 breach
# 991 breached
# 113 breaching
# 248 break
# 117 breaking
# 230 bribe
# 96 bribery
# 156 bridge
# 184 brief
# 104 briefly
# 89 brigade
# 1009 bring
# 561 bringing
# 108 britain
# 301 british
# 136 broad
# 240 broadcast
# 244 broadcasting
# 275 broke
# 524 broken
# 1551 brother
# 4524 brought
# 109 brown
# 969 bruise
# 135 bruising
# 108 brussels
# 849 bucharest
# 106 bucket
# 370 budapest
# 501 budget
# 91 budgetary
# 106 build
# 2615 building
# 253 built
# 1073 bulgaria
# 649 bulgarian
# 504 bullet
# 295 bunk
# 589 burden
# 348 bureau
# 150 burgas
# 159 burglary
# 124 burial
# 127 burn
# 98 buromenskiy
# 115 burst
# 252 bus
# 182 butkevych
# 99 butt
# 210 buy
# 147 buyer
# 256 bvr
# 95 caa
# 189 cabinet
# 240 cabral
# 128 cadastral
# 244 caf
# 100 cage
# 389 calculated
# 274 calculation
# 1405 call
# 2173 called
# 181 calling
# 178 calm
# 981 came
# 335 camera
# 746 camouflage
# 450 camp
# 343 campaign
# 108 canada
# 285 cancelled
# 95 cancer
# 725 candidate
# 105 cannabis
# 2645 cannot
# 201 cao
# 159 cap
# 558 capable
# 1705 capacity
# 306 capital
# 255 captain
# 3709 car
# 406 card
# 95 cardiac
# 128 cardiologist
# 90 cardiology
# 4001 care
# 118 careful
# 131 carefully
# 4040 carried
# 115 carrier
# 1669 carry
# 881 carrying
# 244 cartridge
# 472 casadevall
# 141 cash
# 3818 cassation
# 190 cast
# 636 category
# 224 catholic
# 225 caucasus
# 171 caught
# 190 causal
# 1287 cause
# 3238 caused
# 660 causing
# 258 cc
# 1215 ccp
# 1416 ccrp
# 144 cd
# 140 ce
# 217 cease
# 346 ceased
# 370 cec
# 119 ceiling
# 124 celejewski
# 171 celje
# 7863 cell
# 161 cellmates
# 177 cemetery
# 117 censored
# 150 censorship
# 174 cent
# 104 center
# 234 centimetre
# 1299 central
# 5333 centre
# 130 cerebral
# 109 ceremony
# 3498 certain
# 128 certainly
# 230 certainty
# 1918 certificate
# 317 certified
# 114 cf
# 431 ch
# 246 chair
# 394 chairman
# 1208 challenge
# 1529 challenged
# 430 challenging
# 5582 chamber
# 152 chance
# 1497 change
# 850 changed
# 185 changing
# 230 channel
# 1333 chapter
# 672 character
# 204 characterisation
# 168 characterised
# 289 characteristic
# 6094 charge
# 3138 charged
# 161 charging
# 401 charter
# 109 charzy
# 1254 chechen
# 1185 chechnya
# 1068 check
# 396 checked
# 107 checking
# 779 checkpoint
# 158 chelyabinsk
# 102 chemical
# 642 chest
# 293 chi
# 1302 chief
# 11128 child
# 406 choice
# 189 choose
# 280 choosing
# 295 chosen
# 212 christian
# 505 christos
# 517 chronic
# 140 chu
# 864 church
# 200 ci
# 112 cia
# 159 cigarette
# 127 cinema
# 333 circuit
# 120 circulation
# 11528 circumstance
# 1896 cited
# 198 citing
# 1597 citizen
# 337 citizenship
# 3675 city
# 96 civic
# 10389 civil
# 937 civilian
# 8944 claim
# 1083 claimant
# 2910 claimed
# 936 claiming
# 158 clan
# 210 clarification
# 198 clarified
# 244 clarify
# 187 clash
# 336 class
# 220 classification
# 560 classified
# 675 claudia
# 195 clause
# 225 clean
# 125 cleaning
# 1289 clear
# 96 clearance
# 766 clearly
# 133 clemency
# 686 client
# 414 clinic
# 426 clinical
# 1044 close
# 788 closed
# 266 closely
# 92 closer
# 128 closing
# 617 clothes
# 235 clothing
# 181 club
# 167 cluj
# 752 cm
# 2382 co
# 119 cocaine
# 13837 code
# 248 coercion
# 200 coercive
# 328 cold
# 125 coll
# 136 collaboration
# 136 collaborator
# 541 colleague
# 251 collect
# 830 collected
# 101 collecting
# 282 collection
# 363 collective
# 94 college
# 118 collusion
# 104 cologne
# 111 colombo
# 258 colonel
# 1195 colony
# 206 colour
# 90 column
# 216 combat
# 138 combating
# 112 combination
# 150 combined
# 1195 come
# 313 coming
# 507 command
# 1268 commander
# 114 commanding
# 90 commence
# 379 commenced
# 110 commencement
# 1180 comment
# 190 commented
# 1141 commercial
# 3893 commission
# 314 commissioned
# 712 commissioner
# 839 commit
# 149 commitment
# 121 commits
# 110 committal
# 5711 committed
# 3494 committee
# 703 committing
# 706 common
# 129 commonwealth
# 145 communal
# 878 communicate
# 1843 communicated
# 1264 communication
# 391 communist
# 1302 community
# 726 company
# 164 comparable
# 116 comparative
# 197 compared
# 104 comparison
# 147 compartment
# 193 compatibility
# 391 compatible
# 90 compelled
# 97 compelling
# 166 compensate
# 263 compensated
# 5865 compensation
# 658 competence
# 2496 competent
# 90 competition
# 125 compiled
# 370 complain
# 796 complainant
# 9171 complained
# 541 complaining
# 16724 complaint
# 578 complete
# 1046 completed
# 292 completely
# 300 completion
# 414 complex
# 344 complexity
# 1381 compliance
# 103 complication
# 91 complicity
# 857 complied
# 1651 comply
# 136 complying
# 4384 composed
# 392 composition
# 328 comprehensive
# 201 comprised
# 146 comprising
# 624 compulsory
# 315 computer
# 106 conceded
# 212 concept
# 1678 concern
# 4369 concerned
# 10129 concerning
# 412 conclude
# 3633 concluded
# 224 concludes
# 268 concluding
# 2705 conclusion
# 343 concrete
# 170 concussion
# 9659 condition
# 207 conditional
# 252 conditioned
# 2969 conduct
# 2630 conducted
# 429 conducting
# 231 conec
# 173 conference
# 99 conferred
# 257 confess
# 319 confessed
# 1065 confession
# 339 confidence
# 329 confidential
# 197 confidentiality
# 219 confined
# 584 confinement
# 399 confirm
# 166 confirmation
# 2904 confirmed
# 527 confirming
# 169 confirms
# 257 confiscated
# 689 confiscation
# 1067 conflict
# 101 conflicting
# 344 conformity
# 431 confrontation
# 114 confronted
# 618 conjunction
# 347 connected
# 3236 connection
# 153 conscience
# 241 consciousness
# 135 conscript
# 1428 consent
# 140 consented
# 1386 consequence
# 927 consequently
# 1415 consider
# 479 considerable
# 132 considerably
# 2584 consideration
# 782 considering
# 2087 considers
# 293 consisted
# 460 consistent
# 179 consistently
# 223 consisting
# 115 consists
# 136 consolidated
# 196 conspiracy
# 344 constant
# 225 constantly
# 349 constituency
# 156 constituent
# 796 constitute
# 762 constituted
# 221 constitutes
# 98 constituting
# 3574 constitution
# 9745 constitutional
# 177 constitutionality
# 216 constructed
# 1258 construction
# 106 construed
# 269 consult
# 436 consultation
# 232 consulted
# 90 consumer
# 3033 contact
# 453 contacted
# 801 contain
# 1926 contained
# 636 containing
# 584 contains
# 145 contempt
# 857 contended
# 1179 content
# 112 contention
# 163 contentious
# 203 contest
# 2112 contested
# 112 contesting
# 1491 context
# 262 continuation
# 1518 continue
# 2614 continued
# 185 continues
# 427 continuing
# 214 continuous
# 1452 contract
# 137 contracted
# 606 contracting
# 95 contractual
# 118 contradicted
# 202 contradiction
# 249 contradictory
# 1741 contrary
# 212 contrast
# 371 contravention
# 149 contribute
# 183 contributed
# 892 contribution
# 2176 control
# 227 controlled
# 200 contusion
# 33640 convention
# 969 conversation
# 92 converted
# 428 convict
# 3117 convicted
# 3042 conviction
# 147 convinced
# 351 convincing
# 197 convoy
# 197 cooperate
# 354 cooperation
# 291 cooperative
# 3156 copy
# 109 copyright
# 229 cordon
# 92 core
# 250 corneliu
# 114 corner
# 121 coronary
# 102 corp
# 92 corporal
# 127 corps
# 94 corpse
# 265 corpus
# 519 correct
# 93 corrected
# 278 correction
# 995 correctional
# 462 correctly
# 208 correspond
# 176 corresponded
# 1113 correspondence
# 367 corresponding
# 109 corresponds
# 205 corridor
# 113 corroborate
# 228 corroborated
# 306 corruption
# 239 cost
# 91 cottage
# 3634 council
# 3504 counsel
# 103 counselling
# 766 count
# 97 counted
# 378 counter
# 125 counterclaim
# 111 counterpart
# 561 country
# 2602 county
# 377 couple
# 2946 course
# 175 courthouse
# 311 courtroom
# 278 courtyard
# 125 cousin
# 199 covenant
# 512 cover
# 162 coverage
# 885 covered
# 194 covering
# 159 covert
# 98 cpa
# 1907 cpt
# 94 craiova
# 98 craniocerebral
# 256 create
# 402 created
# 158 creating
# 161 creation
# 247 credibility
# 263 credible
# 138 credit
# 658 creditor
# 185 crew
# 6706 crime
# 134 crimea
# 32782 criminal
# 152 criminally
# 134 crisis
# 698 criterion
# 185 critical
# 270 criticised
# 302 criticism
# 1582 croatia
# 917 croatian
# 456 cross
# 100 crossed
# 183 crossing
# 282 crowd
# 213 crown
# 206 crta
# 216 crucial
# 349 cruel
# 106 cry
# 300 cultural
# 149 culture
# 92 cumulative
# 194 curfew
# 141 currency
# 745 current
# 914 currently
# 597 custodial
# 5373 custody
# 529 custom
# 352 cut
# 222 cypriot
# 395 cyprus
# 97 cz
# 499 czech
# 88 czk
# 170 da
# 188 dagestan
# 961 daily
# 103 dainiai
# 6788 damage
# 258 damaged
# 167 damaging
# 93 damp
# 950 danger
# 724 dangerous
# 94 dangerousness
# 304 danut
# 93 dar
# 160 dark
# 1299 data
# 171 database
# 712 date
# 2414 dated
# 1394 daughter
# 452 david
# 6625 day
# 142 daylight
# 1526 de
# 781 dead
# 272 deadline
# 709 deal
# 696 dealing
# 490 dealt
# 589 dean
# 3537 death
# 187 debate
# 845 debt
# 1086 debtor
# 1089 dec
# 705 deceased
# 1510 decide
# 10167 decided
# 478 decides
# 601 deciding
# 34873 decision
# 258 decisive
# 1222 declaration
# 505 declare
# 2761 declared
# 218 declaring
# 370 declined
# 107 decompression
# 92 decreased
# 1448 decree
# 355 dedov
# 99 deducted
# 203 deed
# 446 deemed
# 539 deems
# 639 defamation
# 248 defamatory
# 313 default
# 280 defect
# 3911 defence
# 472 defend
# 6652 defendant
# 190 defender
# 109 defending
# 246 deficiency
# 824 defined
# 204 defines
# 267 definition
# 2262 degrading
# 860 degree
# 1955 delay
# 294 delayed
# 104 delegate
# 493 delegation
# 139 deliberate
# 4007 deliberated
# 227 deliberately
# 152 deliberation
# 193 delicti
# 210 deliver
# 1359 delivered
# 4020 delivers
# 431 delivery
# 439 demand
# 235 demanded
# 111 demanding
# 136 democracy
# 1051 democratic
# 158 demolition
# 310 demonstrate
# 303 demonstrated
# 952 demonstration
# 331 demonstrator
# 207 denial
# 1761 denied
# 174 denmark
# 142 dental
# 103 dentist
# 146 deny
# 101 denying
# 5464 department
# 270 departure
# 152 depend
# 181 dependent
# 248 depending
# 101 depends
# 97 deployed
# 970 deportation
# 263 deported
# 210 deposit
# 189 deposited
# 163 deposition
# 126 depression
# 1028 deprivation
# 155 deprive
# 2339 deprived
# 136 depriving
# 118 depth
# 2807 deputy
# 194 der
# 214 derblom
# 99 derived
# 127 describe
# 1694 described
# 179 describing
# 928 description
# 118 designate
# 514 designated
# 431 designed
# 125 desirable
# 1537 despite
# 179 destination
# 148 destroy
# 426 destroyed
# 369 destruction
# 1625 detail
# 904 detailed
# 301 detain
# 5367 detained
# 4490 detainee
# 97 detaining
# 96 detect
# 142 detected
# 95 detection
# 28341 detention
# 249 deteriorated
# 286 deterioration
# 2412 determination
# 1067 determine
# 1168 determined
# 460 determining
# 136 detriment
# 99 detrimental
# 169 develop
# 521 developed
# 100 developing
# 1514 development
# 365 device
# 192 di
# 153 diabetes
# 993 diagnosed
# 613 diagnosis
# 164 die
# 1231 died
# 276 diet
# 431 difference
# 2061 different
# 590 difficult
# 618 difficulty
# 693 dignity
# 244 diligence
# 119 diminished
# 220 dimitrov
# 136 din
# 96 dinar
# 315 diplomatic
# 821 direct
# 496 directed
# 699 direction
# 463 directive
# 916 directly
# 1375 director
# 727 directorate
# 200 dirty
# 1411 disability
# 326 disabled
# 108 disadvantage
# 293 disagreed
# 1275 disappearance
# 412 disappeared
# 538 discharge
# 417 discharged
# 1581 disciplinary
# 147 discipline
# 414 disclose
# 646 disclosed
# 121 disclosing
# 897 disclosure
# 99 discontinuance
# 152 discontinuation
# 436 discontinue
# 1277 discontinued
# 726 discovered
# 163 discovery
# 223 discrepancy
# 311 discretion
# 117 discretionary
# 112 discriminated
# 784 discrimination
# 181 discriminatory
# 146 discus
# 316 discussed
# 333 discussion
# 1034 disease
# 89 disinfected
# 346 dismiss
# 829 dismissal
# 7593 dismissed
# 92 dismisses
# 294 dismissing
# 1696 disorder
# 89 disorderly
# 156 dispatched
# 99 disperse
# 228 displaced
# 131 displayed
# 345 disposal
# 405 disproportionate
# 1664 dispute
# 692 disputed
# 113 disqualification
# 112 disregard
# 273 disregarded
# 193 disseminated
# 268 dissemination
# 102 dissenting
# 128 dissolution
# 279 distance
# 219 distinction
# 139 distress
# 168 distributed
# 351 distribution
# 19697 district
# 157 disturbance
# 88 disturbed
# 90 dive
# 176 diver
# 90 divested
# 207 divided
# 293 diving
# 975 division
# 426 divorce
# 370 diyarbak
# 359 dmitry
# 119 dna
# 148 dnipropetrovsk
# 4288 doctor
# 1461 document
# 261 documentary
# 395 documentation
# 172 documented
# 178 dog
# 168 doll
# 197 dollar
# 10917 domestic
# 163 domicile
# 92 donation
# 1077 done
# 297 donetsk
# 1037 door
# 330 dormitory
# 150 double
# 1151 doubt
# 96 dowym
# 1238 dr
# 368 draft
# 406 drafted
# 90 drafting
# 178 dragged
# 310 dragoljub
# 457 draw
# 222 drawing
# 1120 drawn
# 138 dressed
# 421 drew
# 101 drink
# 254 drinking
# 150 drive
# 377 driven
# 762 driver
# 587 driving
# 105 drop
# 184 dropped
# 343 drove
# 2569 drug
# 205 drunk
# 99 dry
# 119 du
# 184 dublin
# 181 dubrovnik
# 3218 due
# 734 duly
# 114 duma
# 860 duration
# 181 duress
# 95 dutch
# 3317 duty
# 204 dwelling
# 339 dze
# 196 dzhabrailov
# 198 ear
# 1199 earlier
# 1360 early
# 147 earnings
# 122 easily
# 166 east
# 168 eastern
# 123 eat
# 200 ec
# 1119 economic
# 124 economy
# 255 editor
# 4047 editorial
# 945 education
# 380 educational
# 3270 effect
# 370 effected
# 3384 effective
# 473 effectively
# 562 effectiveness
# 113 efficient
# 574 effort
# 191 egbert
# 165 egidijus
# 1786 eight
# 469 eighteen
# 205 eighth
# 133 eighty
# 2051 either
# 185 ek
# 238 el
# 259 elapsed
# 114 elbow
# 120 elderly
# 576 elected
# 1605 election
# 834 electoral
# 288 electric
# 160 electricity
# 162 electronic
# 879 element
# 213 elens
# 401 eleven
# 132 eligibility
# 260 eligible
# 138 eliminate
# 194 elisabet
# 740 elisabeth
# 135 elmurzayev
# 205 else
# 144 elsewhere
# 311 embassy
# 178 embezzlement
# 149 emerged
# 663 emergency
# 310 emotional
# 147 emphasis
# 486 emphasised
# 578 employed
# 1346 employee
# 869 employer
# 1143 employment
# 199 empowered
# 101 empty
# 457 enable
# 153 enabling
# 290 enacted
# 143 enactment
# 232 enclosed
# 1587 end
# 98 endanger
# 757 ended
# 245 endorsed
# 208 endorsing
# 1083 enforce
# 505 enforceable
# 872 enforced
# 6980 enforcement
# 96 enforcing
# 219 engage
# 372 engaged
# 126 engaging
# 107 engine
# 128 england
# 173 english
# 293 enjoy
# 209 enjoyed
# 919 enjoyment
# 397 enough
# 349 enquiry
# 139 enshrined
# 336 ensuing
# 2487 ensure
# 261 ensured
# 513 ensuring
# 371 entail
# 143 entailed
# 95 entailing
# 562 enter
# 2187 entered
# 289 entering
# 703 enterprise
# 92 entertain
# 685 entire
# 274 entirely
# 254 entirety
# 5143 entitled
# 297 entitlement
# 949 entity
# 266 entrance
# 91 entrapment
# 254 entrusted
# 1572 entry
# 153 enumerated
# 240 envelope
# 573 environment
# 237 environmental
# 382 envisaged
# 189 episode
# 641 equal
# 402 equality
# 166 equally
# 566 equipment
# 797 equipped
# 498 equivalent
# 95 erdo
# 799 erik
# 175 erred
# 178 erroneous
# 103 erroneously
# 475 error
# 616 escape
# 166 escort
# 193 escorted
# 583 especially
# 223 essence
# 449 essential
# 363 essentially
# 2029 establish
# 5943 established
# 227 establishes
# 764 establishing
# 1445 establishment
# 140 estamirov
# 697 estate
# 184 estimated
# 271 estonia
# 157 estonian
# 291 et
# 298 etc
# 181 ethic
# 94 ethical
# 752 ethnic
# 119 ethnicity
# 219 eu
# 870 euro
# 1186 europe
# 8034 european
# 118 evade
# 465 evaluation
# 126 evasion
# 3108 even
# 557 evening
# 6032 event
# 88 eventual
# 394 eventually
# 447 ever
# 2220 every
# 4436 everyone
# 220 everything
# 111 evi
# 89 evicted
# 383 eviction
# 11554 evidence
# 183 evident
# 104 evidentiary
# 96 ewk
# 625 ex
# 380 exact
# 172 exactly
# 9810 examination
# 4393 examine
# 7229 examined
# 111 examines
# 727 examining
# 1274 example
# 528 exceed
# 467 exceeded
# 523 exceeding
# 1764 except
# 735 exception
# 700 exceptional
# 164 exceptionally
# 160 excerpt
# 156 excess
# 1385 excessive
# 252 excessively
# 398 exchange
# 269 exclude
# 560 excluded
# 146 excluding
# 386 exclusion
# 255 exclusive
# 254 exclusively
# 145 execute
# 309 executed
# 2879 execution
# 613 executive
# 115 exempt
# 172 exempted
# 322 exemption
# 2786 exercise
# 343 exercised
# 309 exercising
# 278 exhaust
# 339 exhausted
# 507 exhaustion
# 115 exhaustive
# 563 exist
# 553 existed
# 939 existence
# 571 existing
# 260 exists
# 136 exit
# 108 expect
# 159 expectation
# 486 expected
# 93 expedite
# 284 expelled
# 672 expense
# 362 experience
# 200 experienced
# 7498 expert
# 126 expertise
# 90 expiration
# 103 expire
# 609 expired
# 631 expiry
# 327 explain
# 1452 explained
# 161 explaining
# 1267 explanation
# 197 explanatory
# 117 explicit
# 255 explicitly
# 146 exploitation
# 237 explosion
# 251 explosive
# 92 expose
# 246 exposed
# 95 exposure
# 532 express
# 1126 expressed
# 174 expressing
# 1273 expression
# 392 expressly
# 234 expropriated
# 642 expropriation
# 907 expulsion
# 661 extend
# 2761 extended
# 468 extending
# 1801 extension
# 337 extensive
# 902 extent
# 263 external
# 267 extortion
# 177 extra
# 994 extract
# 129 extracted
# 174 extradite
# 459 extradited
# 3351 extradition
# 411 extraordinary
# 174 extreme
# 360 extremely
# 100 extremism
# 244 extremist
# 687 eye
# 319 eyewitness
# 103 fabricated
# 1310 face
# 319 faced
# 328 facie
# 191 facilitate
# 4953 facility
# 163 facing
# 13600 fact
# 208 facto
# 690 factor
# 269 factory
# 929 factual
# 134 faculty
# 312 fail
# 5380 failed
# 359 failing
# 268 fails
# 3419 failure
# 2354 fair
# 197 fairness
# 387 faith
# 1075 fall
# 316 fallen
# 368 falling
# 749 false
# 109 familiarise
# 5943 family
# 3317 far
# 133 faris
# 148 farm
# 140 fatal
# 135 fate
# 2924 father
# 116 fatih
# 249 fato
# 362 fault
# 1305 favour
# 205 favourable
# 93 fax
# 858 fear
# 142 feared
# 266 feature
# 4486 federal
# 4461 federation
# 1333 fee
# 124 feel
# 241 feeling
# 601 fell
# 330 fellow
# 317 felt
# 257 female
# 168 fence
# 101 fide
# 400 field
# 1122 fifteen
# 2633 fifth
# 265 fifty
# 511 fight
# 124 fighter
# 150 fighting
# 277 figure
# 540 file
# 2377 filed
# 147 filing
# 142 filled
# 122 film
# 1127 finally
# 611 finance
# 1217 financial
# 2669 find
# 4281 finding
# 1805 fine
# 236 fined
# 209 finger
# 225 fingerprint
# 148 finished
# 378 finland
# 198 finnish
# 572 fire
# 689 firearm
# 422 fired
# 112 firing
# 212 firm
# 329 firstly
# 319 fit
# 3509 five
# 115 fix
# 830 fixed
# 107 flag
# 104 flagrant
# 3010 flat
# 99 flaw
# 200 fled
# 152 flee
# 254 fleeing
# 351 flight
# 1049 floor
# 394 fm
# 694 follow
# 970 followed
# 14442 following
# 10501 follows
# 1365 food
# 323 foot
# 167 footage
# 103 football
# 109 forbidden
# 8760 force
# 1162 forced
# 134 forcible
# 158 forcibly
# 91 forcing
# 148 forde
# 129 forearm
# 209 foregoing
# 138 forehead
# 2447 foreign
# 281 foreigner
# 2696 forensic
# 298 forest
# 99 forestry
# 113 forfeiture
# 253 forged
# 306 forgery
# 2435 form
# 693 formal
# 283 formality
# 387 formally
# 151 formation
# 298 formed
# 3178 former
# 107 formerly
# 92 forming
# 117 formulated
# 627 forth
# 693 forty
# 97 forum
# 454 forward
# 1179 forwarded
# 329 foster
# 11795 found
# 227 foundation
# 1463 founded
# 88 foundedness
# 134 founder
# 4055 four
# 441 fourteen
# 3366 fourth
# 297 fracture
# 155 frame
# 604 framework
# 493 fran
# 514 france
# 118 frankfurt
# 751 fraud
# 97 fraudulent
# 1295 free
# 8787 freedom
# 389 freely
# 260 french
# 103 frequency
# 192 frequent
# 295 frequently
# 1370 fresh
# 97 friday
# 877 friend
# 259 friendly
# 742 front
# 185 frontier
# 987 fsb
# 255 fuel
# 223 fulfil
# 257 fulfilled
# 145 fulfilment
# 984 fully
# 823 function
# 347 functioning
# 1442 fund
# 5226 fundamental
# 134 funding
# 106 funeral
# 230 fura
# 336 furnished
# 166 furniture
# 1932 furthermore
# 92 futile
# 589 future
# 360 fz
# 220 ga
# 320 gaetano
# 191 gain
# 109 gained
# 123 game
# 276 gang
# 373 ganna
# 249 garage
# 117 garden
# 553 garlicki
# 271 garrison
# 406 gas
# 149 gate
# 92 gather
# 417 gathered
# 389 gathering
# 2372 gave
# 96 gaz
# 98 gazel
# 1356 gazette
# 116 gbp
# 871 gc
# 492 gda
# 110 gelayev
# 207 gendarme
# 227 gendarmerie
# 163 gender
# 7936 general
# 640 generally
# 205 geneva
# 295 genocide
# 163 genuine
# 700 george
# 433 georgia
# 233 georgian
# 715 german
# 992 germany
# 557 get
# 98 getting
# 142 gift
# 420 giorgio
# 278 giovanni
# 103 girgvliani
# 452 girl
# 105 girlfriend
# 4161 give
# 9202 given
# 848 giving
# 221 glass
# 89 global
# 99 gmbh
# 1181 go
# 172 goal
# 496 going
# 749 gone
# 1637 good
# 98 gospi
# 404 got
# 365 governed
# 768 governing
# 169 government
# 517 governmental
# 1184 governor
# 120 governs
# 182 gowy
# 170 gpo
# 164 grabbed
# 160 grade
# 105 gram
# 276 grand
# 155 grandmother
# 112 grandparent
# 1583 grant
# 4734 granted
# 580 granting
# 428 grave
# 851 gravity
# 376 great
# 199 greater
# 385 greece
# 432 greek
# 227 grenade
# 144 grey
# 157 gri
# 162 grievance
# 162 grievous
# 197 gross
# 9695 ground
# 133 groundless
# 5217 group
# 92 grozev
# 822 grozny
# 1502 guarantee
# 1097 guaranteed
# 100 guaranteeing
# 1003 guard
# 862 guardian
# 335 guardianship
# 131 gudermes
# 458 guerra
# 199 guidance
# 662 guideline
# 252 guido
# 649 guilt
# 1821 guilty
# 970 gun
# 118 gunfire
# 179 gunshot
# 118 gy
# 93 gypsy
# 323 gyulumyan
# 162 habitual
# 249 haematoma
# 124 haemorrhage
# 436 hague
# 183 hair
# 892 hajiyev
# 857 half
# 204 hall
# 112 hamburg
# 2352 hand
# 451 handcuff
# 640 handcuffed
# 115 handcuffing
# 603 handed
# 114 handgun
# 99 handle
# 171 handling
# 233 handwritten
# 114 happen
# 498 happened
# 173 harassment
# 322 hard
# 119 hardly
# 1041 harm
# 142 harmful
# 103 harsh
# 97 hate
# 97 hatred
# 223 hcj
# 4618 head
# 242 headache
# 132 headed
# 173 heading
# 516 headquarters
# 7084 health
# 114 healthcare
# 129 healthy
# 744 hear
# 3420 heard
# 2717 hearing
# 483 heart
# 322 heating
# 140 heavily
# 231 heavy
# 148 height
# 609 heir
# 245 helen
# 227 helena
# 724 help
# 179 helped
# 317 helsinki
# 229 hence
# 346 hepatitis
# 332 hereafter
# 746 hereinafter
# 252 heroin
# 606 herzegovina
# 115 hidden
# 103 hide
# 316 hiding
# 2807 high
# 1418 higher
# 222 highest
# 122 highlighted
# 214 highly
# 126 hinder
# 146 hip
# 549 hirvel
# 120 historical
# 344 history
# 1163 hit
# 237 hitting
# 660 hiv
# 136 hizb
# 465 hoc
# 1146 hold
# 260 holder
# 1541 holding
# 182 hole
# 306 holiday
# 3259 home
# 160 homicide
# 118 homosexual
# 515 honour
# 111 hooliganism
# 132 hope
# 94 hora
# 6488 hospital
# 356 hospitalisation
# 252 hospitalised
# 90 hostel
# 130 hostility
# 314 hot
# 329 hotel
# 2732 hour
# 4451 house
# 193 housed
# 224 household
# 1401 housing
# 8775 however
# 337 hrk
# 407 hrvatske
# 120 hryvnia
# 107 ht
# 94 huf
# 14387 human
# 386 humanitarian
# 156 humanity
# 362 hundred
# 540 hungarian
# 754 hungary
# 174 hunger
# 197 hunting
# 96 hurt
# 1782 husband
# 464 hygiene
# 113 hygienic
# 182 hypertension
# 243 ia
# 140 iauliai
# 142 ibid
# 261 ibragim
# 127 ibragimov
# 160 ice
# 430 idea
# 456 identical
# 661 identification
# 1188 identified
# 1362 identify
# 275 identifying
# 1763 identity
# 235 idp
# 341 ien
# 253 ignored
# 97 igor
# 5795 ii
# 1978 iii
# 285 ik
# 518 ikuta
# 1850 illegal
# 298 illegally
# 127 illegible
# 1292 illness
# 120 ilyasov
# 235 image
# 88 imakayeva
# 583 immediate
# 1971 immediately
# 138 immigrant
# 893 immigration
# 122 imminent
# 267 immovable
# 516 immunity
# 489 impact
# 484 impair
# 100 impaired
# 138 impairment
# 242 impart
# 773 impartial
# 584 impartiality
# 117 impede
# 188 impediment
# 179 implement
# 698 implementation
# 213 implemented
# 176 implementing
# 136 implicated
# 121 implication
# 100 implies
# 608 importance
# 932 important
# 508 impose
# 2303 imposed
# 317 imposing
# 667 imposition
# 114 impossibility
# 1087 impossible
# 149 impression
# 129 imprisoned
# 4756 imprisonment
# 129 improper
# 212 improve
# 271 improved
# 305 improvement
# 102 improving
# 1149 impugned
# 188 impunity
# 197 imputed
# 250 inability
# 197 inaction
# 367 inactivity
# 659 inadequate
# 1644 inadmissible
# 218 inappropriate
# 199 incapable
# 136 incapacitated
# 137 incapacity
# 2688 incident
# 104 incited
# 220 incitement
# 1099 include
# 1512 included
# 301 includes
# 5991 including
# 106 inclusion
# 842 income
# 1160 incompatible
# 277 incomplete
# 174 inconsistency
# 221 inconsistent
# 156 incorporated
# 287 incorrect
# 115 incorrectly
# 493 increase
# 624 increased
# 149 increasing
# 94 incriminate
# 245 incriminating
# 174 incumbent
# 297 incurred
# 741 indeed
# 132 indefinite
# 438 independence
# 1563 independent
# 117 independently
# 107 index
# 813 indicate
# 2386 indicated
# 272 indicates
# 635 indicating
# 741 indication
# 344 indicted
# 1685 indictment
# 116 indirect
# 93 indirectly
# 5067 individual
# 96 individually
# 109 industrial
# 153 industry
# 628 ineffective
# 170 ineffectiveness
# 265 ineta
# 318 inf
# 150 infected
# 401 infection
# 221 infectious
# 268 inference
# 136 infested
# 114 inflation
# 911 inflicted
# 156 inflicting
# 205 infliction
# 697 influence
# 156 influenced
# 101 influencing
# 1095 inform
# 122 informant
# 7853 informed
# 424 informing
# 107 infrastructure
# 167 infringe
# 464 infringed
# 489 infringement
# 287 ingushetia
# 122 inhabitant
# 160 inherent
# 283 inheritance
# 118 inherited
# 2238 inhuman
# 451 ini
# 1040 initial
# 608 initially
# 479 initiate
# 1101 initiated
# 110 initiation
# 474 initiative
# 156 injection
# 331 injunction
# 858 injured
# 5053 injury
# 2954 inmate
# 131 inner
# 374 innocence
# 220 innocent
# 183 inpatient
# 2112 inquiry
# 107 insect
# 91 inserted
# 735 inside
# 485 insisted
# 126 inski
# 300 insofar
# 401 insolvency
# 106 insolvent
# 155 inspect
# 252 inspected
# 984 inspection
# 620 inspector
# 322 inspectorate
# 212 installation
# 159 installed
# 98 instalment
# 6366 instance
# 284 instant
# 757 instead
# 1937 institute
# 2334 instituted
# 109 instituting
# 2449 institution
# 669 instructed
# 1309 instruction
# 408 instrument
# 903 insufficient
# 251 insult
# 219 insulted
# 206 insulting
# 887 insurance
# 118 insured
# 156 insurgent
# 184 insurrection
# 90 integrated
# 136 integration
# 516 integrity
# 114 intellectual
# 501 intelligence
# 803 intended
# 122 intensity
# 159 intensive
# 303 intent
# 732 intention
# 226 intentional
# 431 intentionally
# 4286 inter
# 160 intercepted
# 361 interception
# 174 intercourse
# 6702 interest
# 341 interested
# 382 interfere
# 161 interfered
# 1304 interference
# 108 interfering
# 1266 interim
# 2040 interior
# 454 interlocutory
# 97 intermediary
# 1608 internal
# 125 internally
# 5541 international
# 97 internationally
# 341 internet
# 732 interpretation
# 528 interpreted
# 248 interpreter
# 134 interrogated
# 321 interrogation
# 147 interrupted
# 101 interruption
# 210 interval
# 386 intervene
# 121 intervened
# 485 intervention
# 1594 interview
# 942 interviewed
# 90 intimate
# 133 intimidation
# 130 intoxication
# 94 introduce
# 793 introduced
# 106 introducing
# 279 introduction
# 226 intruder
# 92 intrusive
# 198 invalid
# 132 invalidity
# 615 investigate
# 305 investigated
# 2496 investigating
# 19441 investigation
# 2160 investigative
# 7668 investigator
# 134 investment
# 124 inviolability
# 165 invite
# 885 invited
# 462 invoked
# 90 invoking
# 411 involuntary
# 196 involve
# 2283 involved
# 1112 involvement
# 649 involving
# 140 iran
# 622 iraq
# 230 iraqi
# 290 ireland
# 200 ireneu
# 175 irkutsk
# 96 iron
# 135 irregular
# 296 irregularity
# 276 irrelevant
# 442 irrespective
# 167 isa
# 602 isabelle
# 172 isayev
# 254 islam
# 250 islamic
# 104 islamist
# 132 island
# 214 ismailov
# 121 isolated
# 220 isolation
# 104 israilov
# 5051 issue
# 5492 issued
# 266 issuing
# 1027 istanbul
# 487 italian
# 810 italy
# 1010 item
# 254 itt
# 108 iu
# 155 iulia
# 974 iv
# 137 ivan
# 487 ivi
# 144 ix
# 804 iz
# 164 izmir
# 102 izvr
# 142 jacket
# 352 jaeger
# 104 jean
# 462 jebens
# 203 jilava
# 351 jo
# 420 job
# 189 johannes
# 502 join
# 217 joinder
# 867 joined
# 1017 joint
# 327 jointly
# 109 jordan
# 411 josep
# 106 journal
# 1009 journalist
# 138 journalistic
# 158 journey
# 6651 judge
# 95 judgement
# 33085 judgment
# 89 judicata
# 5287 judicial
# 572 judiciary
# 441 julia
# 485 jungwiert
# 105 junior
# 2777 jurisdiction
# 228 jurisprudence
# 312 juror
# 659 jury
# 5072 justice
# 345 justification
# 1611 justified
# 651 justify
# 258 justifying
# 482 juvenile
# 357 ka
# 103 kabul
# 432 kalaydjieva
# 187 kaliningrad
# 401 karaka
# 443 karel
# 385 katowice
# 270 kaunas
# 316 kazakhstan
# 493 keep
# 322 keeping
# 244 keller
# 1300 kept
# 356 key
# 119 kg
# 132 kgb
# 258 khad
# 116 khakiyev
# 112 khambulatov
# 116 khamzayev
# 201 khankala
# 807 khanlar
# 598 kharkiv
# 95 khasan
# 95 khashiyev
# 129 kherson
# 151 khizir
# 111 khmelnytskyy
# 186 ki
# 436 kicked
# 152 kicking
# 203 kidnapped
# 897 kidnapping
# 282 kidney
# 131 kielce
# 282 kill
# 964 killed
# 842 killing
# 105 kilometre
# 95 kin
# 498 kind
# 1803 kingdom
# 124 kirovskiy
# 190 kitchen
# 99 kj
# 103 km
# 246 knee
# 419 knew
# 402 knife
# 95 knocked
# 784 know
# 94 knowing
# 90 knowingly
# 675 knowledge
# 1321 known
# 386 ko
# 147 kosovo
# 281 kov
# 776 kovler
# 324 krak
# 109 krasnodar
# 140 krasnoyarsk
# 100 krasuski
# 261 kristina
# 96 krivi
# 214 krzysztof
# 287 ksenija
# 97 kunas
# 93 kurchaloy
# 177 kurd
# 227 kurdish
# 94 kurdistan
# 776 kyiv
# 146 kyrgyz
# 354 kyrgyzstan
# 181 la
# 214 laboratory
# 1064 labour
# 3116 lack
# 529 lacked
# 122 lacking
# 438 laffranque
# 1240 laid
# 96 lamp
# 3664 land
# 92 landlord
# 284 lanka
# 103 lankan
# 109 lapse
# 260 laptev
# 1409 large
# 150 largely
# 108 larger
# 1293 last
# 885 lasted
# 176 lasting
# 1022 lastly
# 530 late
# 3411 later
# 355 latest
# 2831 latter
# 467 latvia
# 233 latvian
# 150 launched
# 112 laundering
# 222 lavatory
# 1505 law
# 2383 lawful
# 707 lawfully
# 1090 lawfulness
# 402 lawrence
# 10798 lawyer
# 1004 lay
# 716 lazarova
# 1431 le
# 619 lead
# 445 leader
# 112 leadership
# 601 leading
# 157 leaflet
# 394 learned
# 105 learning
# 364 learnt
# 278 lease
# 1958 least
# 3019 leave
# 587 leaving
# 101 lebanon
# 476 lech
# 814 led
# 443 ledi
# 590 lef
# 4147 left
# 666 leg
# 11862 legal
# 322 legality
# 577 legally
# 1964 legislation
# 622 legislative
# 110 legislator
# 174 legislature
# 703 legitimate
# 106 lei
# 118 lema
# 148 lemmens
# 3337 length
# 523 lengthy
# 215 lenient
# 91 leningrad
# 327 leninskiy
# 147 lesion
# 391 let
# 5505 letter
# 2259 level
# 98 li
# 1589 liability
# 1305 liable
# 93 libel
# 2586 liberty
# 614 licence
# 134 licensing
# 455 lie
# 88 liechtenstein
# 191 lieutenant
# 8862 life
# 180 lifer
# 185 lift
# 322 lifted
# 2024 light
# 281 lighting
# 732 like
# 229 likelihood
# 757 likely
# 304 likewise
# 198 limb
# 3575 limit
# 835 limitation
# 1334 limited
# 782 line
# 126 linen
# 579 link
# 399 linked
# 360 lino
# 122 lip
# 234 liquidation
# 128 liquidator
# 124 lira
# 2052 list
# 822 listed
# 191 lit
# 679 lithuania
# 423 lithuanian
# 153 litigation
# 296 little
# 98 liu
# 1351 live
# 1127 lived
# 112 liver
# 1826 living
# 109 lj
# 390 ljiljana
# 323 ljubljana
# 174 lmaz
# 146 lng
# 189 loan
# 3395 local
# 879 located
# 480 location
# 90 lock
# 216 locked
# 134 locus
# 1275 lodge
# 12326 lodged
# 810 lodging
# 201 log
# 276 london
# 2076 long
# 1737 longer
# 207 look
# 210 looked
# 244 looking
# 700 lord
# 647 lorenzen
# 351 lorry
# 106 lose
# 885 loss
# 762 lost
# 154 lot
# 112 loucaides
# 405 low
# 1774 lower
# 127 ltd
# 175 ltl
# 185 ltte
# 379 lu
# 115 lubarda
# 269 lublin
# 103 lugansk
# 421 luis
# 99 luki
# 100 lumbar
# 279 lung
# 168 lustration
# 161 lviv
# 252 lying
# 390 macedonia
# 241 macedonian
# 347 machine
# 116 magadan
# 237 magazine
# 341 magistrate
# 105 magomadov
# 491 magomed
# 115 mahoney
# 249 mail
# 1563 main
# 437 mainly
# 454 maintain
# 1821 maintained
# 448 maintaining
# 671 maintenance
# 611 major
# 824 majority
# 3028 make
# 1342 making
# 257 male
# 102 malik
# 486 malinverni
# 513 malta
# 194 maltese
# 96 mammadov
# 1193 man
# 112 manage
# 414 managed
# 743 management
# 240 manager
# 92 managing
# 271 mandate
# 547 mandatory
# 114 manifest
# 622 manifestly
# 1798 manner
# 114 manslaughter
# 140 map
# 94 march
# 102 margin
# 89 maria
# 112 marialena
# 248 maribor
# 104 marino
# 874 mark
# 147 marked
# 396 market
# 110 marko
# 704 marriage
# 436 married
# 119 marry
# 1272 martan
# 358 maruste
# 443 mask
# 249 masked
# 126 masri
# 555 mass
# 167 master
# 110 match
# 109 materiae
# 5800 material
# 108 maternity
# 4317 matter
# 240 mattress
# 90 maturity
# 540 matyushkin
# 1017 maximum
# 942 mayor
# 130 mdl
# 279 meal
# 3020 mean
# 1442 meaning
# 143 meaningful
# 358 meant
# 959 meantime
# 494 meanwhile
# 10056 measure
# 585 measured
# 103 measurement
# 1072 measuring
# 103 meat
# 362 mechanism
# 13653 medical
# 97 medically
# 639 medication
# 899 medicine
# 1468 medium
# 721 meet
# 1918 meeting
# 160 mehmet
# 6567 member
# 590 membership
# 125 memorandum
# 149 memorial
# 121 memory
# 3120 men
# 1993 mental
# 276 mentally
# 436 mention
# 2931 mentioned
# 300 mere
# 557 merely
# 5087 merit
# 95 mesker
# 158 message
# 1385 met
# 652 metal
# 603 method
# 1790 metre
# 88 mhpa
# 101 mi
# 108 mid
# 160 middle
# 97 midnight
# 228 migrant
# 904 migration
# 304 mihai
# 455 mijovi
# 129 milan
# 305 milinchuk
# 7696 military
# 119 militia
# 237 million
# 675 mind
# 133 mine
# 1016 minimum
# 100 mining
# 3367 minister
# 6591 ministry
# 111 minivan
# 1720 minor
# 568 minority
# 273 minsk
# 1229 minute
# 716 mirjana
# 209 misconduct
# 122 misdemeanour
# 110 missed
# 597 missing
# 304 mission
# 215 mistake
# 107 mitigating
# 121 mixed
# 139 mm
# 130 mn
# 512 mobile
# 186 model
# 125 modification
# 257 modified
# 100 mogadishu
# 107 mokot
# 551 moldova
# 321 moldovan
# 654 moment
# 222 monetary
# 1402 money
# 250 monitor
# 220 monitored
# 705 monitoring
# 329 montenegro
# 1860 month
# 492 monthly
# 100 monument
# 916 moral
# 2253 moreover
# 680 morning
# 138 mortem
# 3084 moscow
# 123 mosque
# 233 mostly
# 3707 mother
# 116 motif
# 1325 motion
# 266 motivated
# 148 motoc
# 127 motor
# 125 mouth
# 120 movable
# 468 move
# 660 moved
# 722 movement
# 194 moving
# 167 mp
# 91 mpeanu
# 482 much
# 92 mudayev
# 103 mukayev
# 103 multi
# 302 multiple
# 2687 municipal
# 1221 municipality
# 120 murad
# 2271 murder
# 113 murdered
# 108 mure
# 309 musa
# 106 musayev
# 201 muslim
# 102 mustafa
# 248 mutandis
# 248 mutatis
# 179 mutual
# 230 myjer
# 99 mykhaylo
# 406 na
# 109 nadterechniy
# 279 naismith
# 143 naked
# 2306 name
# 329 named
# 1590 namely
# 277 narcotic
# 97 naruszenie
# 212 nasimi
# 1039 nation
# 9698 national
# 551 nationality
# 1312 natural
# 2373 nature
# 111 nazran
# 190 nd
# 154 ne
# 700 near
# 285 nearby
# 147 nearly
# 447 neboj
# 200 necessarily
# 6986 necessary
# 421 necessity
# 354 neck
# 3129 need
# 847 needed
# 691 negative
# 293 negligence
# 117 negligent
# 157 negotiation
# 951 neighbour
# 168 neighbourhood
# 140 neighbouring
# 1282 neither
# 120 nephew
# 100 nervous
# 95 net
# 733 netherlands
# 291 network
# 156 neurological
# 202 neurologist
# 1792 never
# 787 nevertheless
# 443 newly
# 665 news
# 1034 newspaper
# 1374 next
# 581 ngo
# 244 ni
# 661 nicolaou
# 546 nicolas
# 985 nielsen
# 96 nieuzasadnionej
# 1306 night
# 190 nik
# 89 nikolovska
# 646 nina
# 945 nine
# 106 nineteen
# 104 ninety
# 146 ninth
# 101 niva
# 261 nizhniy
# 2613 no
# 140 nobody
# 531 noise
# 89 nok
# 142 nom
# 99 nominated
# 458 nona
# 660 none
# 218 nonetheless
# 137 noon
# 468 norm
# 388 normal
# 397 normally
# 104 normative
# 510 north
# 360 northern
# 224 norway
# 159 norwegian
# 186 nose
# 296 notably
# 253 notary
# 7285 noted
# 650 nothing
# 2954 notice
# 384 noticed
# 667 notification
# 1062 notified
# 256 notify
# 839 noting
# 198 notion
# 512 notwithstanding
# 266 novgorod
# 123 novi
# 143 novosibirsk
# 386 nu
# 434 null
# 121 nullity
# 6714 number
# 1464 numerous
# 290 nurse
# 112 nursery
# 167 nursing
# 106 oara
# 137 oath
# 106 obey
# 1322 object
# 622 objected
# 2433 objection
# 827 objective
# 164 objectively
# 4658 obligation
# 128 obligatory
# 124 oblige
# 1067 obliged
# 143 observance
# 1785 observation
# 211 observe
# 1852 observed
# 238 observer
# 728 observes
# 122 observing
# 281 obstacle
# 496 obstruct
# 148 obstructing
# 1825 obtain
# 2681 obtained
# 565 obtaining
# 186 obvious
# 176 obviously
# 2349 occasion
# 153 occasionally
# 232 occupancy
# 97 occupant
# 281 occupation
# 150 occupational
# 425 occupied
# 106 occupier
# 89 occupy
# 139 occupying
# 148 occur
# 799 occurred
# 89 occurring
# 232 odessa
# 10613 offence
# 916 offender
# 152 offending
# 148 offensive
# 625 offer
# 839 offered
# 122 offering
# 15699 office
# 15228 officer
# 6947 official
# 323 officially
# 288 officio
# 818 often
# 411 og
# 114 oglu
# 124 oikeus
# 152 oil
# 488 oise
# 107 oki
# 197 okr
# 273 oktyabrskiy
# 1223 old
# 142 older
# 117 olga
# 125 om
# 735 ombudsman
# 650 omission
# 128 omitted
# 92 omon
# 92 omsk
# 221 one
# 388 ongoing
# 170 onto
# 201 onwards
# 237 op
# 1926 open
# 1804 opened
# 518 opening
# 182 operate
# 207 operated
# 256 operating
# 2962 operation
# 1043 operational
# 501 operative
# 167 operator
# 100 ophthalmologist
# 4358 opinion
# 104 opole
# 101 opponent
# 1394 opportunity
# 228 opposed
# 111 opposing
# 141 opposite
# 490 opposition
# 151 option
# 1175 oral
# 192 orally
# 97 orb
# 16064 order
# 7122 ordered
# 800 ordering
# 590 ordinance
# 847 ordinary
# 107 orenburg
# 581 organ
# 2900 organisation
# 103 organisational
# 174 organise
# 1288 organised
# 345 organiser
# 159 organising
# 269 organization
# 109 orientation
# 1079 origin
# 784 original
# 199 originally
# 4062 originated
# 142 orthodox
# 122 osce
# 4827 others
# 1346 otherwise
# 246 ought
# 918 outcome
# 375 outdoor
# 170 outlined
# 129 outpatient
# 276 outset
# 2098 outside
# 138 outskirt
# 218 outstanding
# 295 ov
# 99 ovd
# 641 overall
# 88 overcome
# 382 overcrowded
# 602 overcrowding
# 127 overruled
# 103 overthrow
# 117 overturned
# 144 owed
# 1159 owing
# 995 owned
# 1942 owner
# 1089 ownership
# 97 pa
# 182 package
# 704 page
# 2060 paid
# 983 pain
# 127 pakistan
# 159 palestinian
# 143 pan
# 1721 panel
# 587 paper
# 181 para
# 144 parade
# 2334 paragraph
# 142 parallel
# 117 paramedic
# 91 paramilitary
# 91 paranoid
# 242 parcel
# 257 pardalos
# 142 pardon
# 3080 parent
# 666 parental
# 97 paris
# 137 parish
# 263 park
# 237 parked
# 1351 parliament
# 587 parliamentary
# 453 parole
# 9566 part
# 349 partial
# 282 partially
# 762 participant
# 798 participate
# 802 participated
# 304 participating
# 1166 participation
# 88 particular
# 1616 particularly
# 100 partisan
# 224 partition
# 875 partly
# 559 partner
# 143 partnership
# 11508 party
# 216 pas
# 359 passage
# 576 passed
# 295 passenger
# 151 passing
# 89 passive
# 212 passos
# 828 passport
# 449 past
# 103 pastor
# 326 paternity
# 2051 patient
# 151 patrol
# 94 pattern
# 319 paul
# 311 paulo
# 2770 pay
# 253 payable
# 231 paying
# 2675 payment
# 90 pdpa
# 506 peace
# 1008 peaceful
# 131 pec
# 2851 pecuniary
# 607 peer
# 159 pejchal
# 95 pen
# 791 penal
# 2415 penalty
# 4581 pending
# 861 penitentiary
# 2551 pension
# 175 pensioner
# 2755 people
# 1441 per
# 177 perceived
# 89 percentage
# 89 pere
# 458 perform
# 486 performance
# 860 performed
# 270 performing
# 812 period
# 153 periodic
# 95 perm
# 923 permanent
# 258 permanently
# 244 permissible
# 950 permission
# 1544 permit
# 544 permitted
# 167 perpetrated
# 1634 perpetrator
# 89 perpetual
# 232 persecuted
# 593 persecution
# 100 persisted
# 140 persistent
# 9175 person
# 3176 personal
# 729 personality
# 427 personally
# 768 personnel
# 306 pertaining
# 140 pertinent
# 89 pest
# 690 petersburg
# 1003 petition
# 100 petitioner
# 102 petrol
# 93 petroleum
# 434 pez
# 224 phase
# 214 phillips
# 716 phone
# 296 photo
# 841 photograph
# 105 phrase
# 2435 physical
# 317 physically
# 231 physician
# 313 picture
# 377 piece
# 91 pillow
# 211 pilot
# 329 pinto
# 108 piro
# 185 pistol
# 208 pkk
# 6154 place
# 2689 placed
# 1295 placement
# 154 placing
# 106 plain
# 1827 plaintiff
# 1047 plan
# 179 plane
# 398 planned
# 510 planning
# 92 plant
# 268 plastic
# 257 plate
# 182 plausible
# 179 play
# 146 played
# 223 plea
# 272 pleaded
# 233 pleading
# 401 plenary
# 90 plenum
# 703 pln
# 107 ploie
# 1757 plot
# 333 plovdiv
# 299 plus
# 90 po
# 274 poalelungi
# 125 pocket
# 3659 point
# 1501 pointed
# 162 pointing
# 92 pol
# 2749 poland
# 23965 police
# 648 policeman
# 756 policy
# 1267 polish
# 2304 political
# 160 politically
# 121 politician
# 255 polling
# 101 poltava
# 976 poor
# 363 popovi
# 748 population
# 154 port
# 98 portion
# 108 portugal
# 191 pose
# 242 posed
# 1865 position
# 742 positive
# 125 posse
# 96 possessed
# 3169 possession
# 1709 possibility
# 3371 possible
# 277 possibly
# 1618 post
# 123 postal
# 119 posted
# 94 postpone
# 424 postponed
# 117 postponement
# 211 postupku
# 402 potential
# 137 potentially
# 238 potocki
# 107 powaniu
# 2828 power
# 213 pozna
# 224 pp
# 135 pr
# 233 practical
# 4308 practice
# 2959 practising
# 493 practitioner
# 179 prague
# 106 prawa
# 4498 pre
# 704 preceding
# 167 precise
# 141 precisely
# 127 preclude
# 106 precluded
# 162 predecessor
# 92 preference
# 112 preferred
# 113 pregnant
# 353 prejudice
# 1854 preliminary
# 240 premature
# 162 premeditated
# 1718 premise
# 503 preparation
# 211 preparatory
# 480 prepare
# 968 prepared
# 127 preparing
# 2046 prescribed
# 200 prescription
# 2373 presence
# 5431 present
# 138 presentation
# 1261 presented
# 107 preserve
# 158 presidency
# 8976 president
# 356 presidential
# 407 presiding
# 521 presidium
# 820 press
# 94 pressing
# 941 pressure
# 620 presumed
# 530 presumption
# 1932 prevent
# 621 prevented
# 525 preventing
# 1397 prevention
# 3263 preventive
# 2623 previous
# 383 price
# 330 prima
# 244 primarily
# 347 primary
# 257 prime
# 371 principal
# 4152 principle
# 102 print
# 200 printed
# 2037 prior
# 600 priority
# 13665 prison
# 4920 prisoner
# 523 privacy
# 7493 private
# 126 privately
# 431 privatisation
# 195 privilege
# 105 pro
# 130 probability
# 146 probable
# 254 probably
# 307 probation
# 1928 problem
# 2530 procedural
# 15217 procedure
# 542 proceed
# 223 proceeded
# 250 proceeds
# 1121 process
# 91 processed
# 213 processing
# 402 produce
# 956 produced
# 121 producing
# 302 product
# 199 production
# 120 prof
# 330 profession
# 1379 professional
# 221 professor
# 211 profile
# 289 profit
# 1029 programme
# 920 progress
# 163 prohibit
# 751 prohibited
# 166 prohibiting
# 705 prohibition
# 111 prohibits
# 383 project
# 248 prolongation
# 553 prolonged
# 101 prolonging
# 173 promised
# 211 promote
# 228 prompt
# 106 prompted
# 421 promptly
# 223 pronounced
# 129 pronouncement
# 1004 proof
# 1133 proper
# 978 properly
# 6890 property
# 96 proportion
# 294 proportionality
# 353 proportionate
# 749 proposal
# 784 proposed
# 100 proscribed
# 339 prosecute
# 435 prosecuted
# ...
# 616 remainder
# 1919 remained
# 906 remaining
# 630 remains
# 4268 remand
# 719 remanded
# 285 remark
# 109 remedied
# 4268 remedy
# 319 remember
# 104 reminded
# 232 remit
# 114 remittal
# 1770 remitted
# 1389 removal
# 338 remove
# 900 removed
# 114 removing
# 226 remuneration
# 887 ren
# 294 renate
# 227 render
# 650 rendered
# 88 rendering
# 102 rendition
# 155 renewal
# 188 renewed
# 115 renovation
# 443 rent
# 195 reoffend
# 180 reoffending
# 187 reopen
# 406 reopened
# 614 reopening
# 289 repair
# 345 repealed
# 93 repeat
# 852 repeated
# 673 repeatedly
# 106 repeating
# 163 replace
# 545 replaced
# 129 replacement
# 1006 replied
# 1858 reply
# 13104 report
# 1360 reported
# 212 reportedly
# 339 reporting
# 653 represent
# 602 representation
# 4747 representative
# 8374 represented
# 274 representing
# 93 represents
# 99 reprimand
# 92 reprisal
# 112 reproduced
# 6732 republic
# 175 republican
# 88 republika
# 462 republike
# 740 reputation
# 16011 request
# 6494 requested
# 1148 requesting
# 1023 require
# 3241 required
# 3495 requirement
# 459 requires
# 445 requiring
# 336 requisite
# 325 research
# 133 reservation
# 103 reserve
# 212 reserved
# 194 reside
# 187 resided
# 2578 residence
# 968 resident
# 299 residential
# 276 residing
# 121 resist
# 505 resistance
# 298 resisted
# 116 resisting
# 1489 resolution
# 210 resolve
# 273 resolved
# 200 resort
# 404 resource
# 95 respect
# 363 respected
# 504 respective
# 2095 respectively
# 187 respond
# 243 responded
# 1564 respondent
# 1290 response
# 1873 responsibility
# 2109 responsible
# 463 rest
# 128 restaurant
# 898 restitution
# 195 restoration
# 252 restore
# 239 restored
# 554 restraint
# 168 restrict
# 525 restricted
# 108 restricting
# 1525 restriction
# 217 restrictive
# 5682 result
# 709 resulted
# 656 resulting
# 274 resume
# 1359 resumed
# 143 resumption
# 151 retain
# 345 retained
# 226 retention
# 218 retired
# 451 retirement
# 134 retracted
# 303 retrial
# 130 retroactive
# 234 retrospective
# 2473 return
# 2165 returned
# 254 returning
# 95 rev
# 216 reveal
# 516 revealed
# 130 revenue
# 201 reversed
# 4235 review
# 565 reviewed
# 239 reviewing
# 196 revised
# 4030 revision
# 253 revocation
# 139 revoke
# 292 revoked
# 425 rgvinsson
# 231 ri
# 322 rib
# 243 rifle
# 145 riga
# 24929 right
# 96 rightly
# 255 rijeka
# 329 riot
# 93 ripa
# 521 rise
# 4091 risk
# 102 risked
# 90 river
# 182 rizvan
# 227 rk
# 111 rmen
# 827 road
# 120 roadblock
# 1099 robbery
# 162 robert
# 129 rodki
# 90 rogatory
# 123 rol
# 719 role
# 606 rom
# 125 roman
# 1415 romania
# 967 romanian
# 165 roof
# 1970 room
# 338 rostov
# 404 rouble
# 321 round
# 130 routine
# 96 routinely
# 588 rozakis
# 97 rozpoznania
# 294 rsan
# 129 rsd
# 207 rsfsr
# 910 rub
# 285 rubber
# 10287 rule
# 803 ruled
# 2306 ruling
# 848 run
# 603 running
# 129 rur
# 177 ruslan
# 108 ruslanbek
# 5934 russia
# 10905 russian
# 94 rustam
# 90 ryazan
# 173 rzesz
# 146 sa
# 119 sad
# 131 sadulayeva
# 362 safe
# 600 safeguard
# 1446 safety
# 2771 said
# 455 saj
# 148 salambek
# 726 salary
# 988 sale
# 133 sally
# 113 samara
# 90 sambiyev
# 305 sample
# 118 san
# 842 sanction
# 100 sandro
# 98 sandstr
# 771 sanitary
# 261 santiago
# 167 sat
# 565 satisfaction
# 548 satisfactory
# 680 satisfied
# 337 satisfy
# 102 sauna
# 794 save
# 182 saving
# 922 saw
# 865 say
# 134 sayd
# 376 saying
# 296 scale
# 131 scan
# 141 scar
# 1403 scene
# 451 schedule
# 1397 scheduled
# 450 scheme
# 114 schizophrenia
# 1544 school
# 154 science
# 185 scientific
# 965 scope
# 142 scratch
# 98 screaming
# 110 screening
# 185 scrutiny
# 577 se
# 206 sea
# 106 sealed
# 3227 search
# 570 searched
# 125 searching
# 305 seat
# 183 secondary
# 307 secondly
# 194 secrecy
# 1086 secret
# 809 secretary
# 1072 section
# 265 sector
# 1251 secure
# 337 secured
# 243 securing
# 176 seeing
# 921 seek
# 825 seeker
# 1769 seeking
# 113 seem
# 94 seemed
# 178 seems
# 2297 seen
# 127 seimas
# 92 seize
# 839 seized
# 700 seizure
# 122 selected
# 128 selection
# 1096 self
# 282 sell
# 218 selling
# 214 senate
# 376 send
# 160 sending
# 590 senior
# 294 sense
# 178 sensitive
# 3102 sent
# 6565 sentence
# 3060 sentenced
# 378 sentencing
# 1490 separate
# 514 separated
# 310 separately
# 255 separation
# 198 seq
# 907 serbia
# 322 serbian
# 94 serf
# 293 sergeant
# 158 sergey
# 3981 serious
# 426 seriously
# 376 seriousness
# 324 servant
# 896 serve
# 2727 served
# 1997 service
# 3298 serviceman
# 1302 serving
# 795 session
# 615 set
# 453 setting
# 155 settle
# 303 settled
# 906 settlement
# 1717 seven
# 177 seventeen
# 302 seventh
# 208 seventy
# 5136 several
# 99 severance
# 964 severe
# 312 severely
# 465 severity
# 516 sex
# 1191 sexual
# 134 sexually
# 105 sfry
# 621 sh
# 155 shaipov
# 407 shali
# 837 share
# 447 shared
# 285 shareholder
# 338 shchiborshch
# 261 sheet
# 113 shift
# 91 shifted
# 335 ship
# 114 shirt
# 197 shock
# 126 shoe
# 108 shokkarov
# 298 shooting
# 364 shop
# 758 short
# 489 shortcoming
# 526 shortly
# 673 shot
# 342 shoulder
# 185 shouted
# 220 shouting
# 1357 show
# 910 showed
# 569 shower
# 438 showing
# 730 shown
# 133 shumkov
# 154 si
# 131 siac
# 115 sibling
# 360 sicilianos
# 202 sick
# 895 side
# 92 siedlce
# 359 siewicz
# 98 sight
# 1025 sign
# 580 signature
# 1456 signed
# 174 significance
# 898 significant
# 356 significantly
# 99 signing
# 202 silent
# 182 silvis
# 129 simferopol
# 2407 similar
# 237 similarly
# 210 simple
# 327 simply
# 151 simultaneously
# 752 single
# 128 sink
# 95 sir
# 210 sisak
# 609 sister
# 479 sit
# 882 site
# 4706 sitting
# 540 situated
# 3917 situation
# 3663 six
# 251 sixteen
# 453 sixth
# 239 sixty
# 266 size
# 1035 sizo
# 189 sjc
# 638 sk
# 97 skardze
# 277 ski
# 143 skill
# 173 skin
# 93 skk
# 321 skopje
# 92 slavic
# 305 sleep
# 553 sleeping
# 88 slight
# 117 slightly
# 104 slogan
# 397 slovak
# 564 slovakia
# 500 slovenia
# 252 slovenian
# 703 small
# 127 smaller
# 89 smear
# 102 smoke
# 113 smoker
# 131 smoking
# 123 smuggling
# 153 sobering
# 4221 social
# 221 socialist
# 146 socially
# 1662 society
# 104 sodi
# 834 sofia
# 113 soft
# 480 sold
# 647 soldier
# 432 sole
# 528 solely
# 273 solicitor
# 312 solitary
# 196 solution
# 122 solve
# 105 somali
# 190 somalia
# 98 somebody
# 481 someone
# 294 something
# 332 sometimes
# 4424 son
# 686 soon
# 93 soud
# 2090 sought
# 247 sound
# 947 source
# 287 south
# 217 southern
# 115 sovetskiy
# 291 soviet
# 833 space
# 188 spain
# 222 speak
# 163 speaking
# 4450 special
# 431 specialised
# 1022 specialist
# 295 specially
# 2148 specific
# 537 specifically
# 1364 specified
# 431 specify
# 148 specifying
# 300 speech
# 158 speed
# 209 speedily
# 102 speedy
# 198 spend
# 683 spent
# 268 sphere
# 635 spielmann
# 100 spinal
# 108 spine
# 180 spite
# 376 split
# 95 spo
# 338 spoke
# 211 spoken
# 250 sport
# 156 spot
# 366 spouse
# 99 sprawy
# 160 spread
# 103 spreading
# 94 spring
# 981 sq
# 128 squad
# 1510 square
# 438 sri
# 182 srji
# 92 srpska
# 1033 st
# 183 sta
# 106 stabbed
# 146 stability
# 218 stable
# 1747 staff
# 1631 stage
# 104 stair
# 142 stake
# 296 stamp
# 480 stand
# 1523 standard
# 115 standi
# 654 standing
# 183 standpoint
# 95 stanislav
# 272 stanley
# 90 stara
# 94 staropromyslovskiy
# 458 start
# 1944 started
# 258 starting
# 3411 state
# 9959 stated
# 208 stateless
# 1451 stating
# 3667 station
# 219 stationed
# 104 statistic
# 113 statistical
# 3053 status
# 746 statute
# 1485 statutory
# 1336 stay
# 1021 stayed
# 209 staying
# 797 steiner
# 1765 step
# 184 stephen
# 94 stick
# 2866 still
# 346 stipulated
# 221 stipulates
# 183 stock
# 337 stolen
# 229 stomach
# 179 stone
# 243 stood
# 675 stop
# 779 stopped
# 306 storage
# 92 store
# 133 stored
# 154 story
# 4265 strasbourg
# 159 strategy
# 116 street
# 330 stress
# 956 stressed
# 306 strict
# 282 strictly
# 946 strike
# 169 striking
# 108 strip
# 98 stripped
# 585 strong
# 194 strongly
# 96 strony
# 292 struck
# 97 structural
# 318 structure
# 325 student
# 235 studied
# 748 study
# 160 studying
# 419 sub
# 7880 subject
# 3098 subjected
# 3916 submission
# 1810 submit
# 118 submits
# 11779 submitted
# 331 submitting
# 178 subordinate
# 94 subparagraph
# 526 subsection
# 1883 subsequent
# 3211 subsequently
# 399 subsidiary
# 1031 substance
# 563 substantial
# 157 substantially
# 206 substantiate
# 259 substantiated
# 619 substantive
# 192 substitute
# 90 substitution
# 135 succeeded
# 284 success
# 184 successful
# 115 successfully
# 126 succession
# 217 successor
# 590 sud
# 120 sudan
# 90 suddenly
# 263 sued
# 227 suffer
# 1607 suffered
# 1690 suffering
# 132 suffers
# 100 suffice
# 2665 sufficient
# 585 sufficiently
# 95 sugar
# 278 suggest
# 595 suggested
# 112 suggesting
# 123 suggestion
# 101 suggests
# 566 suicide
# 121 suit
# 349 suitable
# 128 suleymanov
# 1162 sum
# 897 summarised
# 790 summary
# 383 summer
# 219 summon
# 796 summoned
# 762 summons
# 103 sunday
# 116 superficial
# 570 superior
# 125 supervise
# 207 supervised
# 424 supervising
# 1300 supervision
# 99 supervisor
# 1320 supervisory
# 183 supplement
# 187 supplementary
# 164 supplemented
# 233 supplied
# 428 supply
# 2178 support
# 757 supported
# 139 supporter
# 252 supporting
# 159 supposed
# 10272 supreme
# 261 surcharge
# 131 sure
# 344 surface
# 198 surgeon
# 617 surgery
# 194 surgical
# 122 surname
# 224 surrender
# 139 surrounded
# 285 surrounding
# 1016 surveillance
# 122 survivor
# 2443 suspect
# 1226 suspected
# 552 suspend
# 2086 suspended
# 100 suspending
# 758 suspension
# 89 suspensive
# 2365 suspicion
# 116 suspicious
# 1445 sustained
# 112 sverdlovsk
# 98 sverdlovskiy
# 384 sverre
# 92 swearing
# 546 sweden
# 212 swedish
# 130 swelling
# 222 swiss
# 428 switzerland
# 88 swollen
# 112 sworn
# 254 symptom
# 151 syndrome
# 339 syria
# 145 syrian
# 2587 system
# 176 systematic
# 133 systematically
# 108 systemic
# 188 szczecin
# 144 ta
# 639 table
# 123 tahrir
# 119 tahsin
# 150 tajik
# 553 tajikistan
# 105 tajikistani
# 6146 take
# 2568 taking
# 234 taliban
# 251 talk
# 167 talked
# 142 talking
# 102 tall
# 123 tallinn
# 107 tambov
# 98 tamerlan
# 153 tamil
# 110 tank
# 111 tap
# 226 tape
# 93 tapping
# 165 target
# 192 targeted
# 169 tariff
# 92 tashkent
# 701 task
# 2991 tax
# 188 taxation
# 255 taxi
# 131 taxpayer
# 284 tb
# 239 tbilisi
# 355 teacher
# 173 teaching
# 487 team
# 121 tear
# 582 technical
# 216 technique
# 106 technology
# 92 telecommunication
# 1355 telephone
# 669 television
# 220 tell
# 101 telling
# 251 temperature
# 283 temporarily
# 1957 temporary
# 2356 ten
# 390 tenancy
# 310 tenant
# 116 tendency
# 157 tension
# 167 tenth
# 3745 term
# 156 terminal
# 416 terminate
# 1176 terminated
# 121 terminating
# 583 termination
# 478 territorial
# 1312 territory
# 105 terror
# 504 terrorism
# 777 terrorist
# 1463 test
# 110 tested
# 770 testified
# 322 testify
# 1584 testimony
# 225 testing
# 755 text
# 1095 th
# 776 theft
# 180 theory
# 162 therapeutic
# 578 therapy
# 561 thereafter
# 512 thereby
# 241 therein
# 617 thereof
# 165 thereto
# 114 thief
# 114 thigh
# 753 thing
# 205 think
# 5440 third
# 313 thirteen
# 1039 thirty
# 363 thorough
# 152 thoroughly
# 803 though
# 387 thought
# 238 thousand
# 1332 threat
# 116 threaten
# 791 threatened
# 639 threatening
# 145 threshold
# 124 threw
# 712 throughout
# 95 throwing
# 195 thrown
# 3739 thus
# 235 ti
# 129 ticket
# 236 tie
# 209 tied
# 1757 time
# 198 timely
# 134 timi
# 234 timur
# 109 tip
# 155 tirana
# 336 tissue
# 848 title
# 389 tjan
# 145 today
# 101 todorov
# 2269 together
# 1008 toilet
# 94 toiletry
# 2484 told
# 3761 took
# 109 tool
# 150 top
# 284 tort
# 4259 torture
# 362 tortured
# 1110 total
# 93 totally
# 101 touch
# 1100 towards
# 3790 town
# 374 trace
# 93 track
# 438 trade
# 568 traffic
# 575 trafficking
# 181 train
# 146 trained
# 626 training
# 716 trajkovska
# 582 transaction
# 478 transcript
# 2382 transfer
# 3048 transferred
# 149 transferring
# 246 transit
# 240 transitional
# 157 translation
# 116 transmission
# 442 transmitted
# 152 transpires
# 796 transport
# 216 transportation
# 375 transported
# 367 trauma
# 276 traumatic
# 515 travel
# 180 travelled
# 167 travelling
# 565 treasury
# 240 treat
# 1844 treated
# 159 treating
# 12832 treatment
# 602 treaty
# 13727 trial
# 2560 tribunal
# 1213 tried
# 173 trip
# 148 trl
# 109 trnc
# 263 troop
# 174 truck
# 637 true
# 529 truncheon
# 209 trust
# 393 truth
# 329 try
# 343 trying
# 89 tsatsa
# 151 tsentralniy
# 112 tsirli
# 458 tsotsoria
# 106 tsurov
# 146 tten
# 92 tu
# 1281 tuberculosis
# 171 tula
# 365 tulkens
# 124 tunisia
# 121 tunisian
# 2463 turkey
# 1149 turkish
# 287 turkovi
# 435 turn
# 405 turned
# 182 turning
# 290 tv
# 110 tverskoy
# 736 twelve
# 1856 twenty
# 681 twice
# 184 twin
# 13596 two
# 123 tymczasowe
# 1189 type
# 112 tyre
# 113 tyumen
# 581 uah
# 480 uaz
# 258 uga
# 148 uk
# 4040 ukraine
# 1468 ukrainian
# 127 ulcer
# 186 ultimately
# 161 umarov
# 593 un
# 1506 unable
# 130 unaccented
# 173 unacceptable
# 195 unacknowledged
# 97 unanswered
# 312 unauthorised
# 152 unaware
# 98 uncertainty
# 197 unchanged
# 152 uncle
# 367 unclear
# 377 unconstitutional
# 135 und
# 354 undercover
# 536 undergo
# 125 undergoing
# 217 undergone
# 171 underlined
# 264 underlying
# 140 undermine
# 100 undermined
# 346 understand
# 214 understanding
# 334 understood
# 307 undertake
# 413 undertaken
# 618 undertaking
# 116 undertook
# 601 underwent
# 100 undoubtedly
# 365 undue
# 93 unduly
# 114 unemployed
# 117 unemployment
# 140 unenforced
# 444 unfair
# 132 unfairness
# 152 unfit
# 589 unfounded
# 613 unhcr
# 654 unidentified
# 1120 uniform
# 351 unilateral
# 1101 union
# 3555 unit
# 194 unitary
# 3489 united
# 97 universal
# 517 university
# 518 unjustified
# 1018 unknown
# 3977 unlawful
# 990 unlawfully
# 239 unlawfulness
# 1296 unless
# 177 unlike
# 138 unlikely
# 138 unlimited
# 264 unnecessary
# 174 unpaid
# 390 unreasonable
# 164 unreasonably
# 167 unrelated
# 118 unreliable
# 132 unsatisfactory
# 102 unsound
# 2618 unspecified
# 717 unsubstantiated
# 328 unsuccessful
# 349 unsuccessfully
# 252 untrue
# 95
# C:\Users\danny\AppData\Local\Enthought\Canopy\User\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\danny\AppData\Local\Enthought\Canopy\User\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# unwilling
# 131 upanijski
# 135 upbringing
# 100 update
# 112 updated
# 5161 upheld
# 148 uphold
# 204 upholding
# 3430 upon
# 330 upper
# 90 ups
# 202 ural
# 139 urban
# 193 urged
# 124 urgency
# 497 urgent
# 158 urine
# 1030 urus
# 307 usd
# 5432 use
# 3728 used
# 93 useful
# 177 user
# 1111 using
# 149 usman
# 213 ussr
# 120 ustav
# 182 ustavni
# 226 ustawa
# 138 usual
# 304 usually
# 141 ut
# 823 uzbek
# 1504 uzbekistan
# 95 vague
# 700 vaji
# 132 vakhit
# 152 valeriu
# 1038 valid
# 334 validity
# 97 valuable
# 182 valuation
# 163 value
# 712 van
# 121 vara
# 171 varied
# 2854 various
# 119 varna
# 126 vary
# 109 vat
# 319 vaz
# 133 vehabovi
# 2643 vehicle
# 107 velkhiyev
# 182 venice
# 139 ventilated
# 589 ventilation
# 151 venue
# 171 veracity
# 177 verbal
# 168 verbally
# 150 verbatim
# 266 verdict
# 128 verification
# 215 verified
# 416 verify
# 89 verifying
# 1173 version
# 141 vessel
# 155 vested
# 151 veteran
# 733 vi
# 282 via
# 227 vice
# 220 vicinity
# 4699 victim
# 746 video
# 405 vienna
# 5825 view
# 93 viewed
# 307 vii
# 274 viii
# 89 vilanova
# 1339 village
# 165 villager
# 591 villiger
# 316 vilnius
# 324 vincent
# 109 vinkovci
# 218 violate
# 1877 violated
# 176 violating
# 9255 violation
# 2232 violence
# 643 violent
# 618 virtue
# 197 visa
# 93 visadi
# 272 visible
# 2983 visit
# 1085 visited
# 241 visiting
# 153 visitor
# 142 visual
# 124 vital
# 92 vitamin
# 262 vladimir
# 167 vladimiro
# 89 vladimirovich
# 109 vocational
# 168 voice
# 527 void
# 277 volgograd
# 130 volodymyr
# 243 volume
# 347 voluntarily
# 305 voluntary
# 282 voronezh
# 541 vote
# 257 voter
# 185 voting
# 294 vovd
# 584 vre
# 466 vu
# 133 vukovar
# 252 vulnerable
# 152 wad
# 173 wage
# 166 wait
# 133 waited
# 330 waiting
# 148 waived
# 137 waiver
# 405 walk
# 111 walked
# 217 walking
# 584 wall
# 178 wampach
# 395 want
# 967 wanted
# 771 war
# 551 ward
# 148 warden
# 297 warder
# 89 warm
# 279 warned
# 441 warning
# 1390 warrant
# 117 warranted
# 1167 warsaw
# 122 warszawa
# 135 wash
# 94 washing
# 92 waste
# 371 watch
# 1289 water
# 3397 way
# 664 weapon
# 89 wear
# 538 wearing
# 251 website
# 1334 week
# 149 weekend
# 191 weekly
# 267 weight
# 107 welcome
# 873 welfare
# 1581 went
# 128 west
# 743 westerdiek
# 111 western
# 110 wet
# 142 whatever
# 102 whatsoever
# 99 wheelchair
# 229 whenever
# 967 whereabouts
# 655 whereas
# 292 whereby
# 456 whilst
# 282 white
# 90 whoever
# 894 whole
# 120 wholly
# 2329 whose
# 292 wide
# 146 widely
# 97 wider
# 208 widespread
# 236 widow
# 1867 wife
# 164 willing
# 1203 window
# 327 wing
# 213 winter
# 127 wire
# 1155 wish
# 565 wished
# 244 withdraw
# 392 withdrawal
# 342 withdrawn
# 303 withdrew
# 7693 without
# 9095 witness
# 445 witnessed
# 377 wo
# 199 wojtyczek
# 101 woken
# 1345 woman
# 152 wooden
# 550 word
# 265 worded
# 283 wording
# 3071 work
# 714 worked
# 610 worker
# 1300 working
# 112 workplace
# 90 workshop
# 424 world
# 96 worn
# 91 worsened
# 116 worth
# 622 wound
# 243 wounded
# 304 wrist
# 655 writ
# 170 write
# 864 writing
# 2978 written
# 237 wroc
# 266 wrong
# 347 wrongful
# 97 wrongfully
# 238 wrongly
# 842 wrote
# 127 xi
# 128 xii
# 240 ya
# 478 yard
# 94 yasamal
# 180 ye
# 10497 year
# 354 yerevan
# 1128 yet
# 115 yevgeniy
# 644 young
# 98 younger
# 320 youth
# 167 yu
# 379 yudkivska
# 359 yugoslav
# 263 yugoslavia
# 108 yuriy
# 395 yurt
# 406 za
# 104 zadar
# 857 zagreb
# 213 zagrebelsky
# 91 zagrebu
# 844 zakon
# 129 zapobiegawcze
# 324 zaytsev
# 94 zcan
# 423 zdravka
# 142 zelimkhan
# 152 zh
# 297 ziemele
# 146 zloty
# 188 zmir
# 443 zone
# 441 zupan
# 100 zvan
# 96 zw
# Training the random forest...
# [mean: 0.98105, std: 0.01290, params: {}]

# %%
print test.shape

# Create an empty list and append the clean reviews one by one
num_reviews = len(test["sentences"])
clean_test_reviews = [] 

print "Cleaning and parsing the test set ECHR Cases...\n"
for i in xrange(0,num_reviews):
    if( (i+1) % 100 == 0 ):
        print "Case %d of %d\n" % (i+1, num_reviews)
    clean_review = review_to_words( test["sentences"][i] )
    clean_test_reviews.append( clean_review )
# Out:
# (2348, 9)
# Cleaning and parsing the test set ECHR Cases...
#
# Case 100 of 2348
#
# Case 200 of 2348
#
# Case 300 of 2348
#
# Case 400 of 2348
#
# Case 500 of 2348
#
# Case 600 of 2348
#
# Case 700 of 2348
#
# Case 800 of 2348
#
# Case 900 of 2348
#
# Case 1000 of 2348
#
# Case 1100 of 2348
#
# Case 1200 of 2348
#
# Case 1300 of 2348
#
# Case 1400 of 2348
#
# Case 1500 of 2348
#
# Case 1600 of 2348
#
# Case 1700 of 2348
#
# Case 1800 of 2348
#
# Case 1900 of 2348
#
# Case 2000 of 2348
#
# Case 2100 of 2348
#
# Case 2200 of 2348
#
# Case 2300 of 2348

# %%
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

## Use the random forest to make sentiment label predictions
#result = forest.predict(test_data_features)
#
## Copy the results to a pandas dataframe with an "id" column and
## a "sentiment" column
#output = pd.DataFrame( data={"title":test["title"],"conclusion":test["conclusion"], "AV3_Predict":result} )
#
## Use pandas to write the comma-separated output file
#output.to_csv( "Bag_of_Words_LEMM.csv", index=False, quoting=3, escapechar='\\', sep='^' )

LR_result = model_LR.predict_proba(test_data_features)[:,1] 
#LR_output = pd.DataFrame(data={"id":test["id"], "AV3":LR_result}) # Create our dataframe that will be written.
LR_output = pd.DataFrame( data={"title":test["title"],"conclusion":test["conclusion"], "AV3_Predict":LR_result} )
#LR_output.to_csv('Logistic_Reg_Proj2.csv', index=False, quoting=3) # Get the .csv file we will submit to Kaggle.
LR_output.to_csv( "A3002_Bag_of_Words_LEMM_UNI_CV.csv", index=False, quoting=3, escapechar='\\', sep='^'  )
