# %%
import json
import pandas as pd       
import os
import nltk
from nltk.corpus import stopwords

# Open Trining File
os.chdir("/temp/DocumentCorpus/ECHR/echr_dataset-master/echr_dataset-master/document_crawler/IN/")
train = pd.read_csv("TRAIN_classifiedFULL_NOADMISS.tsv", header=0, delimiter="^", quoting=3)
test  = pd.read_csv("TEST_NOclassifiedFULL_NOADMISS.tsv", header=0, delimiter="^", quoting=3)

os.chdir("/temp/DocumentCorpus/ECHR/echr_dataset-master/echr_dataset-master/document_crawler/OUT/AV3/CV/")

train.shape
test.shape

train.columns.values

from bs4 import BeautifulSoup   
import re

from nltk.stem.porter import *
from nltk import WordNetLemmatizer

def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    
    # 5a. Remove extra Stop words
    moreStopwords = ["b","full","value","file","period","months","additional","basis","street","respect","cases","application","amount","since","costs","address","well","days","series","c","particular","purposes","purpose","proceedings","proceeding","h","able","ba","country","held","board","first","second","final","judge","non","statement","documents","many","notes","note","j","considered","aw","echr","whether","language","ill","time","taken","kh","rovd","must","set","within","p","mr","mrs","provided","sher","one","new","route","routes","three","would","previously","shall","en","k","g","applicants","eur","date","might","paragraph","u","kd","could","made","company","see","public","parking","statements","article","government","business","information","therefore","right","also","applicant","court","act","state","security","section","hearing","v","service","case","law","person","courts","regional","january","february","march","april","may","june","july","august","september","october","november","december"]
    more_meaningful_words = [token for token in meaningful_words if token not in moreStopwords]
    
    #
    # 6. Stemmer
    #stemmed=[]
    #stemmer = PorterStemmer()
    #for word in more_meaningful_words:
    #    stemmed.append(stemmer.stem(word))
        
    #
    # 7. Lemmatizer
    Lemmatized=[]
    Lemmatizer = WordNetLemmatizer()
    for word in more_meaningful_words:
        Lemmatized.append(Lemmatizer.lemmatize(word))
        
    #
    # 8. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( Lemmatized ))  
    #return( " ".join( stemmed ))  
    #return( " ".join( more_meaningful_words ))  
    #return( " ".join( meaningful_words ))   
    
# Get the number of cases based on the dataframe column size

num_reviews = train["sentences"].size

# Initialize an empty list to hold the clean cases
clean_train_sentences = []

# Loop over each case 
for i in xrange( 0, num_reviews ):
    # If the index is evenly divisible by 100, print a message
    if( (i+1)%50 == 0 ):
        print "CASE %d of %d\n" % ( i+1, num_reviews )                                                                    
    clean_train_sentences.append( review_to_words( train["sentences"][i] ))
# Out:
# C:\Users\danny\AppData\Local\Enthought\Canopy\User\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# CASE 50 of 4000
#
# CASE 100 of 4000
#
# CASE 150 of 4000
#
# CASE 200 of 4000
#
# CASE 250 of 4000
#
# CASE 300 of 4000
#
# CASE 350 of 4000
#
# CASE 400 of 4000
#
# CASE 450 of 4000
#
# CASE 500 of 4000
#
# CASE 550 of 4000
#
# CASE 600 of 4000
#
# CASE 650 of 4000
#
# CASE 700 of 4000
#
# CASE 750 of 4000
#
# CASE 800 of 4000
#
# CASE 850 of 4000
#
# CASE 900 of 4000
#
# CASE 950 of 4000
#
# CASE 1000 of 4000
#
# CASE 1050 of 4000
#
# CASE 1100 of 4000
#
# CASE 1150 of 4000
#
# CASE 1200 of 4000
#
# CASE 1250 of 4000
#
# CASE 1300 of 4000
#
# CASE 1350 of 4000
#
# CASE 1400 of 4000
#
# CASE 1450 of 4000
#
# CASE 1500 of 4000
#
# CASE 1550 of 4000
#
# CASE 1600 of 4000
#
# CASE 1650 of 4000
#
# CASE 1700 of 4000
#
# CASE 1750 of 4000
#
# CASE 1800 of 4000
#
# CASE 1850 of 4000
#
# CASE 1900 of 4000
#
# CASE 1950 of 4000
#
# CASE 2000 of 4000
#
# CASE 2050 of 4000
#
# CASE 2100 of 4000
#
# CASE 2150 of 4000
#
# CASE 2200 of 4000
#
# CASE 2250 of 4000
#
# CASE 2300 of 4000
#
# CASE 2350 of 4000
#
# CASE 2400 of 4000
#
# CASE 2450 of 4000
#
# CASE 2500 of 4000
#
# CASE 2550 of 4000
#
# CASE 2600 of 4000
#
# CASE 2650 of 4000
#
# CASE 2700 of 4000
#
# CASE 2750 of 4000
#
# CASE 2800 of 4000
#
# CASE 2850 of 4000
#
# CASE 2900 of 4000
#
# CASE 2950 of 4000
#
# CASE 3000 of 4000
#
# CASE 3050 of 4000
#
# CASE 3100 of 4000
#
# CASE 3150 of 4000
#
# CASE 3200 of 4000
#
# CASE 3250 of 4000
#
# CASE 3300 of 4000
#
# CASE 3350 of 4000
#
# CASE 3400 of 4000
#
# CASE 3450 of 4000
#
# CASE 3500 of 4000
#
# CASE 3550 of 4000
#
# CASE 3600 of 4000
#
# CASE 3650 of 4000
#
# CASE 3700 of 4000
#
# CASE 3750 of 4000
#
# CASE 3800 of 4000
#
# CASE 3850 of 4000
#
# CASE 3900 of 4000
#
# CASE 3950 of 4000
#
# CASE 4000 of 4000

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  

vectorizer = CountVectorizer(analyzer = "word",   \
                             ngram_range=(1, 2),  \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 


# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features=[]
train_data_features = vectorizer.fit_transform(clean_train_sentences)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()

print(train_data_features.shape)

vocab = vectorizer.get_feature_names()
print(vocab)


import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
    
print "Training the random forest..."
#from sklearn.ensemble import RandomForestClassifier

## Initialize a Random Forest classifier with 100 trees
#forest = RandomForestClassifier(n_estimators = 100) 

## Fit the forest to the training set, using the bag of words as 
## features and the sentiment labels as the response variable
##
## This may take a few minutes to run
#forest = forest.fit( train_data_features, train["AV3"] )    

from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

grid_values = {} #{'C':[30]} # Decide which settings you want for the grid search. 

model_LR = GridSearchCV(RandomForestClassifier(n_estimators = 100), 
                        grid_values, 
                        scoring = 'roc_auc', cv = 20) 

# Try to set the scoring on what the contest is asking for. 
# The contest says scoring is for area under the ROC curve, so use this.
                            
model_LR.fit(train_data_features, train["AV3"] ) # Fit the model.

model_LR.grid_scores_
# Out:
# (4000L, 5000L)
# [u'abducted', u'abduction', u'abductor', u'ability', u'abrasion', u'abroad', u'abscond', u'absconding', u'absence', u'absent', u'absentia', u'absolute', u'absolutely', u'absolutely necessary', u'abuse', u'abuse power', u'abused', u'acceded', u'accept', u'acceptable', u'accepted', u'access', u'access lawyer', u'accessible', u'accident', u'accommodated', u'accommodation', u'accompanied', u'accomplice', u'accordance', u'accordance code', u'accordance convention', u'accordance general', u'accordance necessary', u'accordance procedure', u'accordance provision', u'accordance rule', u'according', u'according medical', u'according report', u'accordingly', u'account', u'account event', u'account fact', u'accusation', u'accused', u'achieved', u'achkhoy', u'achkhoy martan', u'acknowledged', u'acquaintance', u'acquire', u'acquired', u'acquisition', u'acquittal', u'acquitted', u'across', u'act', u'acted', u'acting', u'acting official', u'action', u'action lawfully', u'active', u'actively', u'activist', u'activity', u'actual', u'actually', u'acute', u'ad', u'ad hoc', u'adam', u'add', u'added', u'addition', u'additionally', u'address', u'addressed', u'adduced', u'adequate', u'adequate medical', u'adequately', u'adjourned', u'adjournment', u'administered', u'administration', u'administration justice', u'administrative', u'administrative authority', u'administrative decision', u'administrative detention', u'administrative dismissed', u'administrative offence', u'administrative procedure', u'administrator', u'admissibility', u'admissibility fact', u'admissibility merit', u'admissible', u'admission', u'admit', u'admitted', u'adopt', u'adopted', u'adopted procedure', u'adoption', u'adoptive', u'adoptive parent', u'adult', u'advance', u'advanced', u'adversarial', u'adverse', u'advice', u'advised', u'adviser', u'advocate', u'affair', u'affair alleged', u'affect', u'affected', u'affecting', u'afforded', u'afghan', u'afghanistan', u'aforementioned', u'afraid', u'afterwards', u'age', u'agency', u'agent', u'agent wo', u'agent zaytsev', u'aggravated', u'aggressive', u'agree', u'agreed', u'agreement', u'agricultural', u'aid', u'aid lawyer', u'aid represented', u'aim', u'aimed', u'air', u'aircraft', u'airport', u'akhmed', u'al', u'albania', u'albuquerque', u'alcohol', u'alexandre', u'alexandre sicilianos', u'ali', u'alia', u'alien', u'aliyev', u'allegation', u'allegation treatment', u'alleged', u'alleged breach', u'alleged treatment', u'alleged violation', u'allegedly', u'alleging', u'allocated', u'allow', u'allowance', u'allowed', u'allowed appeal', u'allowed claim', u'allowing', u'allows', u'almost', u'alone', u'along', u'already', u'alternative', u'although', u'alvina', u'alvina gyulumyan', u'always', u'ambulance', u'amenable', u'amend', u'amended', u'amendment', u'amnesty', u'amnesty international', u'among', u'among others', u'among thing', u'amongst', u'amount', u'amounted', u'amounting', u'analysed', u'analysis', u'anatoly', u'anatoly kovler', u'andr', u'andr potocki', u'andr saj', u'andr wampach', u'angelika', u'angelika nu', u'ankara', u'ann', u'ann power', u'annex', u'announced', u'annual', u'annulled', u'annulment', u'another', u'answer', u'answer question', u'answered', u'anti', u'anti tuberculosis', u'anyone', u'anything', u'apart', u'apartment', u'apc', u'appalling', u'apparent', u'apparently', u'appeal', u'appeal appeal', u'appeal cassation', u'appeal decision', u'appeal detention', u'appeal dismissed', u'appeal found', u'appeal ii', u'appeal instance', u'appeal judgment', u'appeal lodged', u'appeal noted', u'appeal point', u'appeal prosecutor', u'appeal quashed', u'appeal rejected', u'appeal supreme', u'appeal upheld', u'appealed', u'appealed decision', u'appealed judgment', u'appear', u'appear trial', u'appearance', u'appeared', u'appears', u'appellant', u'appellate', u'appendix', u'applicable', u'application', u'application no', u'applied', u'applies', u'apply', u'apply rule', u'applying', u'applying convention', u'appoint', u'appointed' ...
# 924 abducted
# 3192 abduction
# 611 abductor
# 384 ability
# 307 abrasion
# 537 abroad
# 871 abscond
# 418 absconding
# 2875 absence
# 309 absent
# 197 absentia
# 234 absolute
# 313 absolutely
# 249 absolutely necessary
# 1772 abuse
# 196 abuse power
# 275 abused
# 206 acceded
# 740 accept
# 223 acceptable
# 1505 accepted
# 4269 access
# 179 access lawyer
# 211 accessible
# 848 accident
# 282 accommodated
# 704 accommodation
# 791 accompanied
# 315 accomplice
# 5827 accordance
# 177 accordance code
# 338 accordance convention
# 473 accordance general
# 321 accordance necessary
# 599 accordance procedure
# 419 accordance provision
# 238 accordance rule
# 11027 according
# 248 according medical
# 352 according report
# 1747 accordingly
# 6739 account
# 304 account event
# 209 account fact
# 489 accusation
# 5569 accused
# 203 achieved
# 254 achkhoy
# 224 achkhoy martan
# 825 acknowledged
# 227 acquaintance
# 184 acquire
# 675 acquired
# 221 acquisition
# 236 acquittal
# 641 acquitted
# 230 across
# 3032 act
# 881 acted
# 1546 acting
# 267 acting official
# 7846 action
# 179 action lawfully
# 509 active
# 202 actively
# 251 activist
# 4341 activity
# 522 actual
# 499 actually
# 287 acute
# 671 ad
# 464 ad hoc
# 186 adam
# 178 add
# 1068 added
# 2270 addition
# 209 additionally
# 189 address
# 830 addressed
# 261 adduced
# 1592 adequate
# 388 adequate medical
# 270 adequately
# 1598 adjourned
# 325 adjournment
# 286 administered
# 3257 administration
# 348 administration justice
# 8776 administrative
# 566 administrative authority
# 427 administrative decision
# 264 administrative detention
# 233 administrative dismissed
# 873 administrative offence
# 301 administrative procedure
# 200 administrator
# 3639 admissibility
# 1079 admissibility fact
# 1816 admissibility merit
# 300 admissible
# 1026 admission
# 320 admit
# 1557 admitted
# 413 adopt
# 6499 adopted
# 3909 adopted procedure
# 1418 adoption
# 302 adoptive
# 186 adoptive parent
# 375 adult
# 332 advance
# 236 advanced
# 177 adversarial
# 191 adverse
# 297 advice
# 465 advised
# 209 adviser
# 580 advocate
# 1960 affair
# 442 affair alleged
# 402 affect
# 677 affected
# 220 affecting
# 447 afforded
# 260 afghan
# 650 afghanistan
# 438 aforementioned
# 210 afraid
# 425 afterwards
# 1482 age
# 1902 agency
# 4922 agent
# 348 agent wo
# 229 agent zaytsev
# 871 aggravated
# 290 aggressive
# 299 agree
# 1274 agreed
# 2356 agreement
# 302 agricultural
# 1980 aid
# 277 aid lawyer
# 480 aid represented
# 1099 aim
# 785 aimed
# 862 air
# 313 aircraft
# 465 airport
# 197 akhmed
# 620 al
# 220 albania
# 311 albuquerque
# 423 alcohol
# 359 alexandre
# 359 alexandre sicilianos
# 623 ali
# 3889 alia
# 1132 alien
# 241 aliyev
# 4175 allegation
# 662 allegation treatment
# 12145 alleged
# 179 alleged breach
# 583 alleged treatment
# 4665 alleged violation
# 2105 allegedly
# 807 alleging
# 481 allocated
# 1273 allow
# 605 allowance
# 3609 allowed
# 245 allowed appeal
# 184 allowed claim
# 475 allowing
# 203 allows
# 578 almost
# 814 alone
# 565 along
# 2818 already
# 598 alternative
# 2166 although
# 281 alvina
# 281 alvina gyulumyan
# 651 always
# 540 ambulance
# 180 amenable
# 222 amend
# 1629 amended
# 1531 amendment
# 486 amnesty
# 325 amnesty international
# 1697 among
# 204 among others
# 433 among thing
# 254 amongst
# 477 amount
# 839 amounted
# 245 amounting
# 202 analysed
# 511 analysis
# 664 anatoly
# 663 anatoly kovler
# 891 andr
# 238 andr potocki
# 452 andr saj
# 175 andr wampach
# 349 angelika
# 348 angelika nu
# 414 ankara
# 261 ann
# 256 ann power
# 407 annex
# 276 announced
# 313 annual
# 396 annulled
# 449 annulment
# 5923 another
# 631 answer
# 189 answer question
# 259 answered
# 860 anti
# 182 anti tuberculosis
# 709 anyone
# 505 anything
# 380 apart
# 1123 apartment
# 917 apc
# 180 appalling
# 280 apparent
# 745 apparently
# 26964 appeal
# 432 appeal appeal
# 375 appeal cassation
# 1710 appeal decision
# 186 appeal detention
# 814 appeal dismissed
# 342 appeal found
# 202 appeal ii
# 205 appeal instance
# 893 appeal judgment
# 900 appeal lodged
# 193 appeal noted
# 1382 appeal point
# 191 appeal prosecutor
# 496 appeal quashed
# 276 appeal rejected
# 698 appeal supreme
# 921 appeal upheld
# 4394 appealed
# 732 appealed decision
# 325 appealed judgment
# 2331 appear
# 298 appear trial
# 427 appearance
# 902 appeared
# 2210 appears
# 800 appellant
# 1042 appellate
# 226 appendix
# 2170 applicable
# 2931 application
# 525 application no
# 3745 applied
# 410 applies
# 2377 apply
# 234 apply rule
# 760 applying
# 246 applying convention
# 477 appoint
# 1935 appointed
# 182 appointed expert
# 212 appointed lawyer
# 472 appointment
# 483 apprehended
# 239 apprehension
# 533 approach
# 410 approached
# 2613 appropriate
# 446 approval
# 691 approved
# 1546 approximately
# 304 approximately euro
# 181 apti
# 254 arac
# 252 arac deputy
# 550 arbitrary
# 207 arbitration
# 2923 area
# 3370 argued
# 854 arguing
# 3936 argument
# 340 arise
# 401 arising
# 1101 arm
# 3130 armed
# 184 armed conflict
# 394 armed force
# 569 armed group
# 766 armed men
# 190 armed robbery
# 523 armenia
# 262 armenian
# 525 army
# 1580 around
# 192 arranged
# 818 arrangement
# 398 arrears
# 6523 arrest
# 848 arrest detention
# 185 arrest prevent
# 401 arrest warrant
# 3861 arrested
# 554 arrested detained
# 237 arrested police
# 357 arrested suspicion
# 184 arresting
# 916 arrival
# 1939 arrived
# 300 art
# 4595 article
# 354 article code
# 1542 article convention
# 253 article criminal
# 219 artificial
# 718 aside
# 181 aside decision
# 529 ask
# 5099 asked
# 772 asking
# 422 aslan
# 634 aspect
# 575 ass
# 545 assault
# 211 assaulted
# 1278 assembly
# 334 asserted
# 364 assertion
# 772 assessed
# 559 assessing
# 2938 assessment
# 292 assessment evidence
# 783 asset
# 889 assigned
# 386 assist
# 3576 assistance
# 436 assistant
# 484 assisted
# 843 assize
# 276 associated
# 2027 association
# 281 assumed
# 223 assumption
# 614 assurance
# 3003 asylum
# 818 asylum seeker
# 873 attached
# 1304 attack
# 339 attacked
# 1191 attempt
# 1267 attempted
# 210 attempting
# 1009 attend
# 389 attendance
# 592 attended
# 229 attending
# 887 attention
# 245 attesting
# 376 attitude
# 1625 attorney
# 285 attorney general
# 591 attorney office
# 224 attributable
# 244 attributed
# 240 auction
# 232 audio
# 189 audit
# 801 austria
# 425 austrian
# 318 author
# 918 authorisation
# 240 authorise
# 1772 authorised
# 330 authorising
# 20727 authority
# 179 authority decision
# 336 authority exercise
# 771 authority failed
# 211 authority failure
# 225 authority notwithstanding
# 192 authority reasonable
# 178 authority take
# 273 automatic
# 204 automatically
# 242 autopsy
# 425 avail
# 2877 available
# 215 avenue
# 357 average
# 596 avoid
# 922 award
# 1795 awarded
# 188 awarding
# 994 aware
# 1778 away
# 904 azerbaijan
# 357 azerbaijani
# 2772 back
# 913 background
# 274 bad
# 350 bag
# 762 bail
# 1883 bailiff
# 458 baku
# 278 balance
# 386 ban
# 1365 bank
# 206 bank account
# 502 bankruptcy
# 239 banned
# 1059 bar
# 213 bar association
# 442 barred
# 240 barreto
# 346 base
# 3740 based
# 181 basement
# 182 bashir
# 1014 basic
# 432 bear
# 519 bearing
# 321 bearing mind
# 374 beat
# 1439 beaten
# 254 beaten police
# 921 beating
# 1909 became
# 4744 become
# 848 become circumstance
# 2367 become convention
# 229 becomes
# 180 becoming
# 1263 bed
# 342 bedding
# 800 began
# 590 beginning
# 1229 behalf
# 1232 behaviour
# 578 behind
# 196 behind back
# 335 belarus
# 202 belgium
# 213 belgrade
# 503 belief
# 726 believe
# 274 believed
# 449 belonged
# 883 belonging
# 576 bench
# 1625 benefit
# 359 berger
# 629 berro
# 584 berro lef
# 663 best
# 467 best interest
# 338 better
# 874 beyond
# 272 beyond reasonable
# 504 bgn
# 266 bgn bgn
# 199 bi
# 443 bianku
# 263 bias
# 956 bill
# 652 bill indictment
# 720 binding
# 309 biological
# 611 birth
# 435 bj
# 425 bj rgvinsson
# 224 black
# 183 blanket
# 187 bleeding
# 364 block
# 195 blocked
# 1280 blood
# 430 blow
# 267 blunt
# 470 bo
# 389 bo tjan
# 929 bodily
# 363 bodily harm
# 504 bodily injury
# 5077 body
# 178 body inquiry
# 197 bond
# 181 bone
# 348 bonello
# 202 bonello ljiljana
# 495 book
# 795 border
# 5595 born
# 266 born currently
# 2599 born life
# 454 born respectively
# 622 bosnia
# 605 bosnia herzegovina
# 309 bought
# 518 bound
# 440 boy
# 265 brain
# 568 branch
# 214 bratislava
# 542 bratza
# 466 bratza president
# 3594 breach
# 650 breach convention
# 991 breached
# 248 break
# 230 bribe
# 184 brief
# 1009 bring
# 561 bringing
# 207 bringing competent
# 301 british
# 240 broadcast
# 244 broadcasting
# 275 broke
# 524 broken
# 1551 brother
# 4524 brought
# 282 brought action
# 285 brought civil
# 969 bruise
# 849 bucharest
# 180 bucharest county
# 370 budapest
# 501 budget
# 2615 building
# 253 built
# 1073 bulgaria
# 649 bulgarian
# 504 bullet
# 295 bunk
# 589 burden
# 362 burden proof
# 348 bureau
# 252 bus
# 182 butkevych
# 210 buy
# 256 bvr
# 189 cabinet
# 240 cabral
# 240 cabral barreto
# 244 caf
# 389 calculated
# 274 calculation
# 1405 call
# 2173 called
# 181 calling
# 178 calm
# 981 came
# 248 came force
# 335 camera
# 746 camouflage
# 723 camouflage uniform
# 450 camp
# 343 campaign
# 285 cancelled
# 725 candidate
# 2645 cannot
# 201 cao
# 558 capable
# 1705 capacity
# 306 capital
# 255 captain
# 3709 car
# 406 card
# 4001 care
# 4040 carried
# 1669 carry
# 200 carry duty
# 213 carry effective
# 881 carrying
# 244 cartridge
# 472 casadevall
# 379 casadevall president
# 3818 cassation
# 1127 cassation appeal
# 190 cast
# 636 category
# 224 catholic
# 225 caucasus
# 190 causal
# 1287 cause
# 188 cause death
# 3238 caused
# 660 causing
# 258 cc
# 1215 ccp
# 1416 ccrp
# 217 cease
# 346 ceased
# 370 cec
# 7863 cell
# 184 cell cell
# 237 cell equipped
# 303 cell measured
# 439 cell measuring
# 177 cemetery
# 234 centimetre
# 1299 central
# 5333 centre
# 3498 certain
# 230 certainty
# 1918 certificate
# 400 certificate issued
# 317 certified
# 431 ch
# 246 chair
# 394 chairman
# 1208 challenge
# 1529 challenged
# 307 challenged decision
# 430 challenging
# 5582 chamber
# 4028 chamber composed
# 206 chamber decided
# 1497 change
# 850 changed
# 185 changing
# 230 channel
# 1333 chapter
# 672 character
# 204 characterisation
# 289 characteristic
# 6094 charge
# 345 charge brought
# 495 charge everyone
# 3138 charged
# 404 charged criminal
# 303 charged sentenced
# 237 charged serious
# 401 charter
# 1254 chechen
# 919 chechen republic
# 1185 chechnya
# 216 chechnya prosecutor
# 1068 check
# 396 checked
# 779 checkpoint
# 642 chest
# 293 chi
# 1302 chief
# 210 chief prosecutor
# 11128 child
# 206 child born
# 186 child parent
# 406 choice
# 189 choose
# 280 choosing
# 295 chosen
# 212 christian
# 505 christos
# 502 christos rozakis
# 517 chronic
# 864 church
# 200 ci
# 333 circuit
# 11528 circumstance
# 3045 circumstance born
# 852 circumstance convention
# 1896 cited
# 198 citing
# 1597 citizen
# 337 citizenship
# 3675 city
# 214 city prosecutor
# 279 city upheld
# 10389 civil
# 623 civil action
# 514 civil claim
# 1334 civil code
# 253 civil party
# 1418 civil procedure
# 1398 civil right
# 218 civil servant
# 937 civilian
# 8944 claim
# 357 claim compensation
# 385 claim damage
# 1083 claimant
# 2910 claimed
# 936 claiming
# 210 clarification
# 198 clarified
# 244 clarify
# 187 clash
# 336 class
# 220 classification
# 560 classified
# 675 claudia
# 672 claudia westerdiek
# 195 clause
# 225 clean
# 1289 clear
# 766 clearly
# 686 client
# 414 clinic
# 426 clinical
# 1044 close
# 177 close relative
# 788 closed
# 266 closely
# 617 clothes
# 235 clothing
# 181 club
# 752 cm
# 2382 co
# 688 co accused
# 731 co defendant
# 13837 code
# 447 code administrative
# 1047 code civil
# 3660 code criminal
# 211 code execution
# 276 code force
# 445 code provides
# 248 coercion
# 200 coercive
# 328 cold
# 541 colleague
# 251 collect
# 830 collected
# 282 collection
# 363 collective
# 258 colonel
# 1195 colony
# 206 colour
# 216 combat
# 1195 come
# 313 coming
# 507 command
# 1268 commander
# 493 commander office
# 379 commenced
# 1180 comment
# 190 commented
# 1141 commercial
# 3893 commission
# 203 commission decision
# 314 commissioned
# 712 commissioner
# 839 commit
# 5711 committed
# 308 committed crime
# 327 committed criminal
# 802 committed offence
# 243 committed person
# 3494 committee
# 631 committee minister
# 333 committee prevention
# 703 committing
# 303 committing offence
# 706 common
# 878 communicate
# 531 communicate complaint
# 1843 communicated
# 416 communicated decided
# 632 communicated fact
# 1264 communication
# 391 communist
# 1302 community
# 726 company
# 197 compared
# 193 compatibility
# 391 compatible
# 263 compensated
# 5865 compensation
# 182 compensation awarded
# 262 compensation claim
# 509 compensation damage
# 810 compensation pecuniary
# 658 competence
# 2496 competent
# 645 competent authority
# 214 competent legal
# 370 complain
# 796 complainant
# 9171 complained
# 184 complained authority
# 257 complained condition
# 822 complained convention
# 716 complained length
# 541 complaining
# 16724 complaint
# 1100 complaint concerning
# 306 complaint constitutional
# 428 complaint convention
# 296 complaint decision
# 220 complaint examined
# 291 complaint fall
# 207 complaint inadmissible
# 548 complaint lodged
# 263 complaint prosecutor
# 274 complaint treatment
# 578 complete
# 1046 completed
# 292 completely
# 300 completion
# 414 complex
# 344 complexity
# 1381 compliance
# 857 complied
# 1651 comply
# 4384 composed
# 469 composed christos
# 277 composed fran
# 272 composed isabelle
# 373 composed josep
# 385 composed nicolas
# 217 composed nina
# 344 composed peer
# 392 composition
# 328 comprehensive
# 201 comprised
# 624 compulsory
# 315 computer
# 212 concept
# 1678 concern
# 4369 concerned
# 10129 concerning
# 266 concerning alleged
# 278 concerning length
# 412 conclude
# 3633 concluded
# 224 concludes
# 268 concluding
# 2705 conclusion
# 343 concrete
# 9659 condition
# 2444 condition detention
# 559 condition general
# 207 conditional
# 252 conditioned
# 245 conditioned guarantee
# 2969 conduct
# 2630 conducted
# 429 conducting
# 231 conec
# 257 confess
# 319 confessed
# 1065 confession
# 339 confidence
# 329 confidential
# 197 confidentiality
# 219 confined
# 584 confinement
# 399 confirm
# 2904 confirmed
# 527 confirming
# 257 confiscated
# 689 confiscation
# 1067 conflict
# 344 conformity
# 431 confrontation
# 618 conjunction
# 347 connected
# 3236 connection
# 241 consciousness
# 1428 consent
# 1386 consequence
# 927 consequently
# 1415 consider
# 479 considerable
# 2584 consideration
# 284 consideration began
# 782 considering
# 2087 considers
# 335 considers complaint
# 293 consisted
# 460 consistent
# 179 consistently
# 223 consisting
# 196 conspiracy
# 344 constant
# 225 constantly
# 349 constituency
# 796 constitute
# 762 constituted
# 221 constitutes
# 3574 constitution
# 182 constitution constitutional
# 181 constitution provides
# 182 constitution republic
# 178 constitution ukraine
# 9745 constitutional
# 328 constitutional appeal
# 1121 constitutional complaint
# 198 constitutional constitutional
# 353 constitutional decision
# 246 constitutional declared
# 200 constitutional dismissed
# 321 constitutional found
# 272 constitutional judgment
# 181 constitutional order
# 356 constitutional right
# 177 constitutionality
# 216 constructed
# 1258 construction
# 269 consult
# 436 consultation
# 232 consulted
# 3033 contact
# 236 contact child
# 212 contact right
# 453 contacted
# 801 contain
# 1926 contained
# 636 containing
# 584 contains
# 857 contended
# 1179 content
# 203 contest
# 2112 contested
# 1049 contested argument
# 197 contested decision
# 1491 context
# 262 continuation
# 1518 continue
# 191 continue examination
# 2614 continued
# 473 continued detention
# 185 continues
# 427 continuing
# 214 continuous
# 1452 contract
# 606 contracting
# 269 contracting party
# 202 contradiction
# 249 contradictory
# 1741 contrary
# 237 contrary convention
# 212 contrast
# 371 contravention
# 179 contravention result
# 183 contributed
# 892 contribution
# 390 contribution penalty
# 2176 control
# 456 control use
# 227 controlled
# 200 contusion
# 33640 convention
# 356 convention account
# 232 convention alleged
# 269 convention communicated
# 3266 convention complained
# 1026 convention decided
# 425 convention far
# 260 convention human
# 359 convention polish
# 227 convention president
# 4198 convention protection
# 960 convention protocol
# 374 convention provides
# 2118 convention read
# 389 convention relevant
# 223 convention right
# 370 convention rule
# 731 convention russian
# 3194 convention subject
# 211 convention turkish
# 339 convention two
# 396 convention ukrainian
# 326 convention violated
# 969 conversation
# 428 convict
# 3117 convicted
# 181 convicted person
# 3042 conviction
# 233 conviction crime
# 351 convincing
# 185 convincing explanation
# 197 convoy
# 197 cooperate
# 354 cooperation
# 291 cooperative
# 3156 copy
# 438 copy decision
# 229 cordon
# 250 corneliu
# 247 corneliu rsan
# 265 corpus
# 188 corpus delicti
# 519 correct
# 278 correction
# 995 correctional
# 448 correctional colony
# 236 correctional facility
# 462 correctly
# 208 correspond
# 176 corresponded
# 1113 correspondence
# 195 correspondence interference
# 367 corresponding
# 205 corridor
# 228 corroborated
# 306 corruption
# 239 cost
# 3634 council
# 935 council europe
# 3504 counsel
# 766 count
# 378 counter
# 561 country
# 2602 county
# 199 county dismissed
# 377 couple
# 2946 course
# 305 course investigation
# 311 courtroom
# 278 courtyard
# 199 covenant
# 512 cover
# 885 covered
# 194 covering
# 1907 cpt
# 300 cpt inf
# 256 create
# 402 created
# 247 credibility
# 263 credible
# 658 creditor
# 185 crew
# 6706 crime
# 523 crime committed
# 228 crime penalty
# 466 crime protection
# 583 crime scene
# 32782 criminal
# 214 criminal act
# 410 criminal activity
# 895 criminal charge
# 3674 criminal code
# 770 criminal complaint
# 220 criminal concerning
# 191 criminal conviction
# 227 criminal criminal
# 288 criminal group
# 432 criminal instituted
# 2320 criminal investigation
# 297 criminal liability
# 221 criminal matter
# 2650 criminal offence
# 204 criminal opened
# 360 criminal police
# 4174 criminal procedure
# 472 criminal prosecution
# 323 criminal record
# 178 criminal remedy
# 269 criminal responsibility
# 698 criterion
# 185 critical
# 270 criticised
# 302 criticism
# 1582 croatia
# 917 croatian
# 176 croatian national
# 456 cross
# 183 crossing
# 282 crowd
# 213 crown
# 206 crta
# 216 crucial
# 349 cruel
# 246 cruel inhuman
# 300 cultural
# 194 curfew
# 745 current
# 914 currently
# 177 currently serving
# 597 custodial
# 178 custodial measure
# 5373 custody
# 529 custom
# 352 cut
# 222 cypriot
# 395 cyprus
# 499 czech
# 345 czech republic
# 188 dagestan
# 961 daily
# 6788 damage
# 898 damage caused
# 323 damage sustained
# 258 damaged
# 950 danger
# 724 dangerous
# 304 danut
# 302 danut jo
# 1299 data
# 712 date
# 2414 dated
# 1394 daughter
# 452 david
# 415 david th
# 6625 day
# 1526 de
# 311 de albuquerque
# 320 de gaetano
# 781 dead
# 272 deadline
# 709 deal
# 696 dealing
# 490 dealt
# 589 dean
# 556 dean spielmann
# 3537 death
# 308 death penalty
# 187 debate
# 845 debt
# 1086 debtor
# 1089 dec
# 705 deceased
# 1510 decide
# 10167 decided
# 231 decided apply
# 655 decided communicate
# 1538 decided examine
# 1809 decided give
# 1313 decided rule
# 478 decides
# 601 deciding
# 34873 decision
# 203 decision administrative
# 199 decision adopted
# 717 decision appeal
# 236 decision appealed
# 214 decision became
# 440 decision concerning
# 458 decision constitutional
# 323 decision decision
# 179 decision dismissed
# 262 decision district
# 304 decision given
# 178 decision ii
# 204 decision instance
# 186 decision investigator
# 243 decision issued
# 180 decision making
# 257 decision ordered
# 189 decision ordering
# 307 decision prosecutor
# 261 decision quashed
# 356 decision read
# 368 decision remitted
# 466 decision served
# 322 decision stated
# 546 decision supreme
# 201 decision suspend
# 343 decision upheld
# 258 decisive
# 1222 declaration
# 505 declare
# 2761 declared
# 488 declared inadmissible
# 216 declared partly
# 218 declaring
# 370 declined
# 1448 decree
# 355 dedov
# 256 dedov judge
# 203 deed
# 446 deemed
# 539 deems
# 448 deems necessary
# 639 defamation
# 248 defamatory
# 313 default
# 280 defect
# 3911 defence
# 581 defence counsel
# 310 defence lawyer
# 179 defence unlawful
# 472 defend
# 6652 defendant
# 289 defendant detention
# 190 defender
# 246 deficiency
# 824 defined
# 204 defines
# 267 definition
# 2262 degrading
# 1976 degrading treatment
# 860 degree
# 1955 delay
# 294 delayed
# 493 delegation
# 4007 deliberated
# 3997 deliberated private
# 227 deliberately
# 193 delicti
# 210 deliver
# 1359 delivered
# 322 delivered judgment
# 4020 delivers
# 3997 delivers following
# 431 delivery
# 439 demand
# 235 demanded
# 1051 democratic
# 736 democratic society
# 310 demonstrate
# 303 demonstrated
# 952 demonstration
# 331 demonstrator
# 207 denial
# 1761 denied
# 5464 department
# 252 department federal
# 187 department fsb
# 542 department interior
# 216 department ministry
# 270 departure
# 181 dependent
# 248 depending
# 970 deportation
# 236 deportation order
# 263 deported
# 210 deposit
# 189 deposited
# 1028 deprivation
# 599 deprivation liberty
# 195 deprivation life
# 2339 deprived
# 821 deprived liberty
# 291 deprived life
# 572 deprived possession
# 2807 deputy
# 271 deputy head
# 236 deputy minister
# 440 deputy prosecutor
# 829 deputy registrar
# 194 der
# 214 derblom
# 1694 described
# 179 describing
# 928 description
# 514 designated
# 431 designed
# 1537 despite
# 249 despite fact
# 179 destination
# 426 destroyed
# 369 destruction
# 1625 detail
# 904 detailed
# 301 detain
# 5367 detained
# 271 detained accordance
# 177 detained action
# 184 detained cell
# 189 detained remand
# 4490 detainee
# 28341 detention
# 1255 detention centre
# 177 detention code
# 186 detention condition
# 177 detention decision
# 228 detention detention
# 192 detention effected
# 432 detention extended
# 2041 detention facility
# 189 detention lawful
# 1141 detention order
# 290 detention ordered
# 773 detention pending
# 201 detention police
# 1286 detention remand
# 281 detention unlawful
# 249 deteriorated
# 286 deterioration
# 2412 determination
# 1300 determination civil
# 426 determination criminal
# 1067 determine
# 1168 determined
# 460 determining
# 521 developed
# 1514 development
# 365 device
# 192 di
# 993 diagnosed
# 613 diagnosis
# 1231 died
# 276 diet
# 431 difference
# 2061 different
# 590 difficult
# 618 difficulty
# 693 dignity
# 244 diligence
# 220 dimitrov
# 315 diplomatic
# 821 direct
# 496 directed
# 699 direction
# 463 directive
# 916 directly
# 1375 director
# 727 directorate
# 200 dirty
# 1411 disability
# 326 disabled
# 293 disagreed
# 1275 disappearance
# 412 disappeared
# 538 discharge
# 417 discharged
# 1581 disciplinary
# 414 disclose
# 646 disclosed
# 897 disclosure
# 436 discontinue
# 1277 discontinued
# 726 discovered
# 223 discrepancy
# 311 discretion
# 784 discrimination
# 188 discrimination ground
# 181 discriminatory
# 316 discussed
# 333 discussion
# 1034 disease
# 346 dismiss
# 829 dismissal
# 7593 dismissed
# 244 dismissed action
# 1679 dismissed appeal
# 563 dismissed claim
# 554 dismissed complaint
# 188 dismissed fact
# 692 dismissed request
# 294 dismissing
# 1696 disorder
# 462 disorder crime
# 228 displaced
# 345 disposal
# 405 disproportionate
# 1664 dispute
# 692 disputed
# 273 disregarded
# 193 disseminated
# 268 dissemination
# 279 distance
# 219 distinction
# 351 distribution
# 19697 district
# 312 district decision
# 334 district department
# 465 district dismissed
# 192 district district
# 374 district extended
# 399 district found
# 259 district granted
# 285 district judgment
# 268 district military
# 408 district moscow
# 217 district office
# 312 district ordered
# 551 district police
# 3138 district prosecutor
# 205 district rejected
# 176 diver
# 207 divided
# 293 diving
# 975 division
# 426 divorce
# 370 diyarbak
# 359 dmitry
# 355 dmitry dedov
# 4288 doctor
# 1461 document
# 261 documentary
# 189 documentary evidence
# 395 documentation
# 178 dog
# 197 dollar
# 10917 domestic
# 714 domestic authority
# 219 domestic constitution
# 257 domestic international
# 297 domestic investigation
# 180 domestic legislation
# 2011 domestic practice
# 436 domestic relevant
# 1039 domestic remedy
# 1077 done
# 297 donetsk
# 1037 door
# 330 dormitory
# 1151 doubt
# 1238 dr
# 368 draft
# 406 drafted
# 178 dragged
# 310 dragoljub
# 310 dragoljub popovi
# 457 draw
# 222 drawing
# 1120 drawn
# 421 drew
# 254 drinking
# 377 driven
# 762 driver
# 587 driving
# 184 dropped
# 343 drove
# 2569 drug
# 319 drug trafficking
# 205 drunk
# 184 dublin
# 181 dubrovnik
# 3218 due
# 734 duly
# 860 duration
# 181 duress
# 3317 duty
# 193 duty responsibility
# 204 dwelling
# 339 dze
# 196 dzhabrailov
# 198 ear
# 1199 earlier
# 1360 early
# 469 early registrar
# 212 early retirement
# 200 ec
# 1119 economic
# 265 economic prevention
# 255 editor
# 4047 editorial
# 3935 editorial revision
# 945 education
# 380 educational
# 3270 effect
# 184 effect lawful
# 370 effected
# 182 effected bringing
# 3384 effective
# 192 effective domestic
# 658 effective investigation
# 1036 effective remedy
# 473 effectively
# 562 effectiveness
# 205 effectiveness investigation
# 574 effort
# 191 egbert
# 191 egbert myjer
# 1786 eight
# 256 eight hour
# 358 eight year
# 469 eighteen
# 205 eighth
# 2051 either
# 185 ek
# 238 el
# 259 elapsed
# 576 elected
# 1605 election
# 834 electoral
# 255 electoral commission
# 288 electric
# 879 element
# 213 elens
# 212 elens passos
# 401 eleven
# 260 eligible
# 194 elisabet
# 194 elisabet fura
# 740 elisabeth
# 731 elisabeth steiner
# 205 else
# 311 embassy
# 178 embezzlement
# 663 emergency
# 310 emotional
# 486 emphasised
# 578 employed
# 1346 employee
# 869 employer
# 1143 employment
# 199 empowered
# 457 enable
# 290 enacted
# 232 enclosed
# 1587 end
# 757 ended
# 210 ended thus
# 245 endorsed
# 208 endorsing
# 1083 enforce
# 341 enforce judgment
# 438 enforce law
# 505 enforceable
# 872 enforced
# 6980 enforcement
# 506 enforcement agency
# 492 enforcement authority
# 179 enforcement decision
# 801 enforcement judgment
# 214 enforcement officer
# 206 enforcement official
# 197 enforcement order
# 219 engage
# 372 engaged
# 293 enjoy
# 209 enjoyed
# 919 enjoyment
# 707 enjoyment possession
# 397 enough
# 349 enquiry
# 336 ensuing
# 2487 ensure
# 261 ensured
# 513 ensuring
# 371 entail
# 562 enter
# 2187 entered
# 1012 entered force
# 289 entering
# 703 enterprise
# 685 entire
# 274 entirely
# 254 entirety
# 5143 entitled
# 1042 entitled fair
# 557 entitled peaceful
# 617 entitled reasonable
# 259 entitled trial
# 297 entitlement
# 949 entity
# 266 entrance
# 254 entrusted
# 1572 entry
# 652 entry force
# 240 envelope
# 573 environment
# 237 environmental
# 382 envisaged
# 189 episode
# 641 equal
# 402 equality
# 566 equipment
# 797 equipped
# 498 equivalent
# 799 erik
# 384 erik jebens
# 411 erik se
# 178 erroneous
# 475 error
# 616 escape
# 180 escape lawfully
# 193 escorted
# 583 especially
# 223 essence
# 449 essential
# 363 essentially
# 2029 establish
# 5943 established
# 227 establishes
# 764 establishing
# 1445 establishment
# 214 establishment fact
# 697 estate
# 184 estimated
# 271 estonia
# 291 et
# 198 et seq
# 298 etc
# 181 ethic
# 752 ethnic
# 219 eu
# 870 euro
# 1186 europe
# 8034 european
# 326 european committee
# 469 european convention
# 5666 european human
# 180 european prison
# 319 european union
# 465 evaluation
# 3108 even
# 629 even though
# 557 evening
# 6032 event
# 296 event question
# 394 eventually
# 447 ever
# 2220 every
# 566 every natural
# 4436 everyone
# 296 everyone arrested
# 223 everyone charged
# 1705 everyone entitled
# 264 everyone freedom
# 305 everyone liberty
# 298 everyone life
# 297 everyone private
# 253 everyone whose
# 220 everything
# 383 eviction
# 11554 evidence
# 382 evidence obtained
# 218 evidence submitted
# 246 evidence support
# 210 evidence witness
# 183 evident
# 625 ex
# 286 ex officio
# 380 exact
# 9810 examination
# 271 examination admissibility
# 204 examination appeal
# 282 examination carried
# 183 examination merit
# 185 examination witness
# 4393 examine
# 375 examine complaint
# 1540 examine merit
# 7229 examined
# 208 examined convention
# 353 examined doctor
# 200 examined medical
# 727 examining
# 1274 example
# 528 exceed
# 467 exceeded
# 523 exceeding
# 1764 except
# 311 except accordance
# 556 except interest
# 735 exception
# 700 exceptional
# 376 exceptional circumstance
# 1385 excessive
# 531 excessive length
# 252 excessively
# 398 exchange
# 269 exclude
# 560 excluded
# 386 exclusion
# 255 exclusive
# 254 exclusively
# 309 executed
# 2879 execution
# 249 execution judgment
# 822 execution sentence
# 613 executive
# 322 exemption
# 2786 exercise
# 303 exercise except
# 224 exercise freedom
# 209 exercise right
# 343 exercised
# 309 exercising
# 278 exhaust
# 188 exhaust domestic
# 339 exhausted
# 507 exhaustion
# 385 exhaustion domestic
# 563 exist
# 553 existed
# 939 existence
# 571 existing
# 260 exists
# 486 expected
# 284 expelled
# 672 expense
# 362 experience
# 200 experienced
# 7498 expert
# 192 expert concluded
# 433 expert examination
# 822 expert opinion
# 1154 expert report
# 609 expired
# 631 expiry
# 327 explain
# 1452 explained
# 1267 explanation
# 222 explanation event
# 197 explanatory
# 255 explicitly
# 237 explosion
# 251 explosive
# 246 exposed
# 532 express
# 1126 expressed
# 191 expressed wish
# 1273 expression
# 392 expressly
# 234 expropriated
# 642 expropriation
# 907 expulsion
# 198 expulsion order
# 661 extend
# 217 extend detention
# 2761 extended
# 993 extended detention
# 468 extending
# 299 extending detention
# 1801 extension
# 513 extension detention
# 230 extension order
# 337 extensive
# 902 extent
# 263 external
# 267 extortion
# 177 extra
# 994 extract
# 459 extradited
# 3351 extradition
# 253 extradition order
# 387 extradition request
# 411 extraordinary
# 360 extremely
# 244 extremist
# 687 eye
# 319 eyewitness
# 1310 face
# 319 faced
# 328 facie
# 191 facilitate
# 4953 facility
# 221 facility iz
# 13600 fact
# 3894 fact circumstance
# 215 fact submitted
# 208 facto
# 690 factor
# 269 factory
# 929 factual
# 197 factual legal
# 312 fail
# 5380 failed
# 381 failed appear
# 223 failed carry
# 284 failed comply
# 246 failed provide
# 308 failed take
# 359 failing
# 268 fails
# 3419 failure
# 203 failure appear
# 305 failure comply
# 314 failure identify
# 2354 fair
# 381 fair reasonable
# 627 fair trial
# 587 fair tribunal
# 197 fairness
# 387 faith
# 1075 fall
# 444 fall examined
# 316 fallen
# 368 falling
# 749 false
# 5943 family
# 759 family life
# 529 family member
# 3317 far
# 1527 far relevant
# 2924 father
# 249 fato
# 247 fato arac
# 362 fault
# 1305 favour
# 205 favourable
# 858 fear
# 266 feature
# 4486 federal
# 752 federal constitutional
# 252 federal force
# 264 federal justice
# 180 federal migration
# 229 federal ministry
# 293 federal republic
# 4461 federation
# 939 federation european
# 924 federation lodged
# 1333 fee
# 241 feeling
# 601 fell
# 330 fellow
# 317 felt
# 257 female
# 400 field
# 1122 fifteen
# 299 fifteen year
# 2633 fifth
# 291 fifth decided
# 856 fifth sitting
# 265 fifty
# 511 fight
# 277 figure
# 540 file
# 2377 filed
# 1127 finally
# 611 finance
# 1217 financial
# 2669 find
# 4281 finding
# 1805 fine
# 236 fined
# 209 finger
# 225 fingerprint
# 378 finland
# 198 finnish
# 572 fire
# 689 firearm
# 422 fired
# 212 firm
# 329 firstly
# 319 fit
# 3509 five
# 996 five year
# 830 fixed
# 3010 flat
# 200 fled
# 254 fleeing
# 180 fleeing done
# 351 flight
# 1049 floor
# 394 fm
# 694 follow
# 970 followed
# 14442 following
# 278 following accordance
# 190 following complaint
# 301 following conviction
# 391 following day
# 219 following decision
# 4165 following judgment
# 178 following minimum
# 225 following request
# 10501 follows
# 1432 follows determination
# 244 follows every
# 1156 follows everyone
# 729 follows subjected
# 1365 food
# 323 foot
# 8760 force
# 194 force absolutely
# 598 force material
# 367 force relevant
# 255 force used
# 1162 forced
# 209 foregoing
# 2447 foreign
# 1038 foreign affair
# 376 foreign national
# 281 foreigner
# 2696 forensic
# 399 forensic examination
# 352 forensic expert
# 724 forensic medical
# 323 forensic medicine
# 231 forensic report
# 298 forest
# 253 forged
# 306 forgery
# 2435 form
# 693 formal
# 283 formality
# 387 formally
# 298 formed
# 3178 former
# 315 former representative
# 316 former yugoslav
# 627 forth
# 356 forth convention
# 693 forty
# 243 forty eight
# 454 forward
# 1179 forwarded
# 207 forwarded complaint
# 329 foster
# 11795 found
# 1002 found guilty
# 183 found judgment
# 238 found violation
# 227 foundation
# 1463 founded
# 4055 four
# 377 four hour
# 433 four year
# 441 fourteen
# 3366 fourth
# 385 fourth decided
# 860 fourth sitting
# 297 fracture
# 604 framework
# 493 fran
# 488 fran oise
# 514 france
# 751 fraud
# 1295 free
# 8787 freedom
# 4013 freedom convention
# 942 freedom expression
# 325 freedom forth
# 419 freedom others
# 389 freely
# 260 french
# 192 frequent
# 295 frequently
# 1370 fresh
# 355 fresh consideration
# 353 fresh examination
# 877 friend
# 259 friendly
# 209 friendly settlement
# 742 front
# 185 frontier
# 987 fsb
# 182 fsb officer
# 255 fuel
# 223 fulfil
# 257 fulfilled
# 984 fully
# 823 function
# 347 functioning
# 1442 fund
# 5226 fundamental
# 4355 fundamental freedom
# 353 fundamental right
# 230 fura
# 336 furnished
# 1932 furthermore
# 589 future
# 360 fz
# 220 ga
# 320 gaetano
# 191 gain
# 276 gang
# 373 ganna
# 352 ganna yudkivska
# 249 garage
# 553 garlicki
# 271 garrison
# 406 gas
# 417 gathered
# 389 gathering
# 2372 gave
# 192 gave decision
# 299 gave judgment
# 1356 gazette
# 350 gazette no
# 871 gc
# 492 gda
# 489 gda sk
# 207 gendarme
# 227 gendarmerie
# 7936 general
# 536 general interest
# 219 general jurisdiction
# 764 general office
# 875 general principle
# 316 general prosecutor
# 198 general report
# 218 general rule
# 640 generally
# 205 geneva
# 295 genocide
# 700 george
# 653 george nicolaou
# 433 georgia
# 233 georgian
# 715 german
# 992 germany
# 557 get
# 420 giorgio
# 419 giorgio malinverni
# 278 giovanni
# 274 giovanni bonello
# 452 girl
# 4161 give
# 184 give evidence
# 1884 give notice
# 207 give rise
# 9202 given
# 214 given fact
# 252 given opportunity
# 848 giving
# 221 glass
# 1181 go
# 496 going
# 749 gone
# 1637 good
# 222 good faith
# 404 got
# 365 governed
# 768 governing
# 517 governmental
# 308 governmental organisation
# 1184 governor
# 182 gowy
# 276 grand
# 234 grand chamber
# 1583 grant
# 4734 granted
# 233 granted claim
# 546 granted legal
# 361 granted request
# 422 granted victim
# 580 granting
# 428 grave
# 851 gravity
# 515 gravity charge
# 376 great
# 199 greater
# 385 greece
# 432 greek
# 227 grenade
# 197 gross
# 9695 ground
# 370 ground appeal
# 224 ground believe
# 217 ground detention
# 5217 group
# 301 group armed
# 822 grozny
# 1502 guarantee
# 251 guarantee appear
# 1097 guaranteed
# 185 guaranteed constitution
# 247 guaranteed convention
# 1003 guard
# 862 guardian
# 335 guardianship
# 458 guerra
# 199 guidance
# 662 guideline
# 252 guido
# 249 guido raimondi
# 649 guilt
# 1821 guilty
# 182 guilty charged
# 970 gun
# 179 gunshot
# 323 gyulumyan
# 249 haematoma
# 436 hague
# 312 hague convention
# 183 hair
# 892 hajiyev
# 247 hajiyev dean
# 242 hajiyev mirjana
# 857 half
# 200 half year
# 204 hall
# 2352 hand
# 451 handcuff
# 640 handcuffed
# 603 handed
# 233 handwritten
# 498 happened
# 322 hard
# 1041 harm
# 223 hcj
# 4618 head
# 242 headache
# 516 headquarters
# 7084 health
# 976 health care
# 535 health moral
# 277 health problem
# 744 hear
# 3420 heard
# 263 heard evidence
# 2717 hearing
# 246 hearing adjourned
# 192 hearing scheduled
# 483 heart
# 322 heating
# 231 heavy
# 609 heir
# 245 helen
# 241 helen keller
# 227 helena
# 214 helena derblom
# 724 help
# 179 helped
# 317 helsinki
# 229 hence
# 346 hepatitis
# 332 hereafter
# 746 hereinafter
# 252 heroin
# 606 herzegovina
# 316 hiding
# 2807 high
# 1418 higher
# 222 highest
# 214 highly
# 549 hirvel
# 192 hirvel ledi
# 344 history
# 1163 hit
# 237 hitting
# 660 hiv
# 465 hoc
# 1146 hold
# 260 holder
# 1541 holding
# 182 hole
# 306 holiday
# 3259 home
# 193 home correspondence
# 515 honour
# 6488 hospital
# 356 hospitalisation
# 252 hospitalised
# 314 hot
# 329 hotel
# 2732 hour
# 4451 house
# 237 house arrest
# 209 house lord
# 193 housed
# 224 household
# 1401 housing
# 8775 however
# 440 however way
# 337 hrk
# 407 hrvatske
# 14387 human
# 200 human dignity
# 13515 human right
# 386 humanitarian
# 362 hundred
# 540 hungarian
# 754 hungary
# 197 hunting
# 1782 husband
# 464 hygiene
# 182 hypertension
# 243 ia
# 261 ibragim
# 430 idea
# 456 identical
# 661 identification
# 1188 identified
# 1362 identify
# 338 identify perpetrator
# 275 identifying
# 1763 identity
# 235 idp
# 341 ien
# 253 ignored
# 5795 ii
# 612 ii alleged
# 3386 ii relevant
# 1978 iii
# 426 iii relevant
# 285 ik
# 518 ikuta
# 1850 illegal
# 527 illegal armed
# 298 illegally
# 1292 illness
# 235 image
# 583 immediate
# 1971 immediately
# 893 immigration
# 267 immovable
# 226 immovable property
# 516 immunity
# 489 impact
# 484 impair
# 437 impair enforce
# 242 impart
# 184 impart idea
# 773 impartial
# 380 impartial tribunal
# 584 impartiality
# 188 impediment
# 179 implement
# 698 implementation
# 213 implemented
# 176 implementing
# 608 importance
# 932 important
# 508 impose
# 2303 imposed
# 317 imposing
# 667 imposition
# 1087 impossible
# 4756 imprisonment
# 212 improve
# 271 improved
# 305 improvement
# 1149 impugned
# 311 impugned decision
# 188 impunity
# 197 imputed
# 250 inability
# 197 inaction
# 367 inactivity
# 659 inadequate
# 1644 inadmissible
# 216 inadmissible decided
# 218 inappropriate
# 199 incapable
# 2688 incident
# 220 incitement
# 1099 include
# 1512 included
# 301 includes
# 5991 including
# 842 income
# 1160 incompatible
# 503 incompatible reasonable
# 277 incomplete
# 221 inconsistent
# 287 incorrect
# 493 increase
# 624 increased
# 245 incriminating
# 297 incurred
# 741 indeed
# 438 independence
# 1563 independent
# 460 independent impartial
# 813 indicate
# 2386 indicated
# 272 indicates
# 635 indicating
# 741 indication
# 344 indicted
# 1685 indictment
# 5067 individual
# 628 ineffective
# 265 ineta
# 265 ineta ziemele
# 318 inf
# 401 infection
# 221 infectious
# 268 inference
# 911 inflicted
# 179 inflicted contravention
# 205 infliction
# 697 influence
# 1095 inform
# 7853 informed
# 315 informed decision
# 201 informed investigation
# 179 informed investigator
# 424 informing
# 464 infringed
# 489 infringement
# 287 ingushetia
# 283 inheritance
# 2238 inhuman
# 2018 inhuman degrading
# 451 ini
# 182 ini judge
# 1040 initial
# 608 initially
# 479 initiate
# 248 initiate criminal
# 1101 initiated
# 474 initiative
# 331 injunction
# 858 injured
# 301 injured party
# 5053 injury
# 306 injury caused
# 284 injury sustained
# 2954 inmate
# 240 inmate cell
# 374 innocence
# 220 innocent
# 183 inpatient
# 2112 inquiry
# 735 inside
# 485 insisted
# 300 insofar
# 204 insofar relevant
# 401 insolvency
# 252 inspected
# 984 inspection
# 620 inspector
# 322 inspectorate
# 212 installation
# 6366 instance
# 462 instance decision
# 904 instance judgment
# 284 instant
# 757 instead
# 1937 institute
# 868 institute criminal
# 2334 instituted
# 311 instituted criminal
# 2449 institution
# 196 institution criminal
# 669 instructed
# 1309 instruction
# 408 instrument
# 903 insufficient
# 251 insult
# 219 insulted
# 206 insulting
# 887 insurance
# 184 insurrection
# 516 integrity
# 501 intelligence
# 803 intended
# 303 intent
# 732 intention
# 226 intentional
# 431 intentionally
# 225 intentionally save
# 4286 inter
# 3883 inter alia
# 361 interception
# 6702 interest
# 347 interest child
# 512 interest national
# 390 interest secure
# 574 interest subject
# 341 interested
# 177 interested party
# 382 interfere
# 1304 interference
# 494 interference authority
# 1266 interim
# 646 interim measure
# 2040 interior
# 454 interlocutory
# 179 interlocutory appeal
# 1608 internal
# 422 internal affair
# 5541 international
# 254 international material
# 437 international preceding
# 252 international protection
# 184 international treaty
# 341 internet
# 732 interpretation
# 528 interpreted
# 248 interpreter
# 321 interrogation
# 210 interval
# 386 intervene
# 485 intervention
# 1594 interview
# 942 interviewed
# 793 introduced
# 279 introduction
# 226 intruder
# 198 invalid
# 615 investigate
# 305 investigated
# 2496 investigating
# 798 investigating authority
# 19441 investigation
# 362 investigation abduction
# 352 investigation allegation
# 218 investigation carried
# 247 investigation completed
# 234 investigation conducted
# 676 investigation criminal
# 293 investigation department
# 215 investigation disappearance
# 210 investigation matter
# 206 investigation opened
# 178 investigation pending
# 254 investigation prosecutor
# 298 investigation resumed
# 451 investigation suspended
# 285 investigation trial
# 2160 investigative
# 266 investigative action
# 270 investigative authority
# 184 investigative committee
# 655 investigative measure
# 292 investigative step
# 7668 investigator
# 183 investigator charge
# 434 investigator prosecutor
# 1039 investigator questioned
# 885 invited
# 462 invoked
# 411 involuntary
# 196 involve
# 2283 involved
# 1112 involvement
# 649 involving
# 622 iraq
# 230 iraqi
# 290 ireland
# 200 ireneu
# 200 ireneu cabral
# 296 irregularity
# 276 irrelevant
# 442 irrespective
# 602 isabelle
# 602 isabelle berro
# 254 islam
# 250 islamic
# 214 ismailov
# 220 isolation
# 5051 issue
# 205 issue decision
# 5492 issued
# 458 issued decision
# 177 issued report
# 266 issuing
# 1027 istanbul
# 487 italian
# 810 italy
# 1010 item
# 254 itt
# 974 iv
# 487 ivi
# 487 ivi hirvel
# 804 iz
# 352 jaeger
# 462 jebens
# 251 jebens giorgio
# 203 jilava
# 351 jo
# 335 jo ien
# 420 job
# 189 johannes
# 182 johannes silvis
# 502 join
# 217 joinder
# 189 joinder application
# 867 joined
# 1017 joint
# 231 joint examination
# 327 jointly
# 411 josep
# 411 josep casadevall
# 1009 journalist
# 6651 judge
# 523 judge claudia
# 239 judge fato
# 184 judge fran
# 383 judge lawrence
# 862 judge ren
# 256 judge santiago
# 264 judge stanley
# 33085 judgment
# 4074 judgment adopted
# 634 judgment appeal
# 198 judgment appealed
# 519 judgment became
# 3302 judgment become
# 249 judgment constitutional
# 446 judgment decision
# 274 judgment delivered
# 206 judgment enforced
# 194 judgment european
# 382 judgment favour
# 175 judgment found
# 350 judgment given
# 252 judgment instance
# 298 judgment judgment
# 310 judgment remitted
# 181 judgment served
# 3815 judgment strasbourg
# 776 judgment subject
# 466 judgment supreme
# 315 judgment upheld
# 5287 judicial
# 386 judicial authority
# 689 judicial decision
# 1032 judicial review
# 572 judiciary
# 441 julia
# 438 julia laffranque
# 485 jungwiert
# 2777 jurisdiction
# 228 jurisprudence
# 312 juror
# 659 jury
# 5072 justice
# 279 justice alleged
# 345 justification
# 1611 justified
# 651 justify
# 258 justifying
# 482 juvenile
# 357 ka
# 432 kalaydjieva
# 182 kalaydjieva judge
# 187 kaliningrad
# 401 karaka
# 443 karel
# 432 karel jungwiert
# 385 katowice
# 270 kaunas
# 316 kazakhstan
# 493 keep
# 322 keeping
# 244 keller
# 1300 kept
# 356 key
# 258 khad
# 201 khankala
# 807 khanlar
# 807 khanlar hajiyev
# 598 kharkiv
# 186 ki
# 436 kicked
# 203 kidnapped
# 897 kidnapping
# 282 kidney
# 282 kill
# 964 killed
# 842 killing
# 498 kind
# 1803 kingdom
# 190 kitchen
# 246 knee
# 419 knew
# 402 knife
# 784 know
# 675 knowledge
# 1321 known
# 386 ko
# 281 kov
# 776 kovler
# 405 kovler elisabeth
# 324 krak
# 261 kristina
# 257 kristina pardalos
# 214 krzysztof
# 199 krzysztof wojtyczek
# 287 ksenija
# 285 ksenija turkovi
# 177 kurd
# 227 kurdish
# 776 kyiv
# 354 kyrgyzstan
# 181 la
# 214 laboratory
# 1064 labour
# 3116 lack
# 203 lack effective
# 529 lacked
# 438 laffranque
# 1240 laid
# 452 laid convention
# 3664 land
# 284 lanka
# 260 laptev
# 1409 large
# 312 large number
# 1293 last
# 885 lasted
# 176 lasting
# 1022 lastly
# 530 late
# 3411 later
# 355 latest
# 2831 latter
# 467 latvia
# 233 latvian
# 222 lavatory
# 1505 law
# 437 law deems
# 2383 lawful
# 472 lawful arrest
# 257 lawful order
# 707 lawfully
# 192 lawfully detained
# 177 lawfully quelling
# 1090 lawfulness
# 360 lawfulness detention
# 402 lawrence
# 394 lawrence early
# 10798 lawyer
# 194 lawyer lodged
# 2783 lawyer practising
# 191 lawyer present
# 191 lawyer requested
# 1004 lay
# 404 lay judge
# 716 lazarova
# 716 lazarova trajkovska
# 1431 le
# 619 lead
# 445 leader
# 601 leading
# 394 learned
# 364 learnt
# 278 lease
# 1958 least
# 208 least two
# 3019 leave
# 480 leave appeal
# 587 leaving
# 476 lech
# 475 lech garlicki
# 814 led
# 443 ledi
# 443 ledi bianku
# 590 lef
# 584 lef vre
# 4147 left
# 216 left side
# 666 leg
# 11862 legal
# 1406 legal aid
# 950 legal assistance
# 254 legal authority
# 301 legal capacity
# 181 legal counsel
# 560 legal entitled
# 474 legal entity
# 227 legal ground
# 490 legal provision
# 223 legal remedy
# 212 legal representation
# 401 legal representative
# 307 legal system
# 322 legality
# 577 legally
# 1964 legislation
# 622 legislative
# 703 legitimate
# 191 legitimate interest
# 3337 length
# 205 length criminal
# 313 length detention
# 387 length incompatible
# 178 length pre
# 523 lengthy
# 215 lenient
# 327 leninskiy
# 283 leninskiy district
# 391 let
# 5505 letter
# 491 letter dated
# 210 letter sent
# 206 letter stated
# 2259 level
# 370 level jurisdiction
# 1589 liability
# 1305 liable
# 211 liable damage
# 2586 liberty
# 287 liberty deprived
# 285 liberty save
# 614 licence
# 455 lie
# 191 lieutenant
# 8862 life
# 273 life health
# 214 life home
# 518 life imprisonment
# 229 life intentionally
# 307 life protected
# 180 life regarded
# 328 life sentence
# 350 life threatening
# 180 lifer
# 185 lift
# 322 lifted
# 2024 light
# 281 lighting
# 732 like
# 229 likelihood
# 757 likely
# 304 likewise
# 198 limb
# 3575 limit
# 175 limit lodging
# 835 limitation
# 1334 limited
# 782 line
# 579 link
# 399 linked
# 360 lino
# 359 lino alexandre
# 234 liquidation
# 2052 list
# 822 listed
# 191 lit
# 679 lithuania
# 423 lithuanian
# 296 little
# 1351 live
# 1127 lived
# 1826 living
# 190 living area
# 263 living condition
# 226 living space
# 390 ljiljana
# 386 ljiljana mijovi
# 323 ljubljana
# 189 loan
# 3395 local
# 407 local authority
# 219 local police
# 229 local self
# 879 located
# 480 location
# 216 locked
# 1275 lodge
# 267 lodge appeal
# 190 lodge complaint
# 12326 lodged
# 1279 lodged appeal
# 195 lodged claim
# 775 lodged complaint
# 357 lodged constitutional
# 3985 lodged convention
# 223 lodged criminal
# 361 lodged request
# 810 lodging
# 224 lodging appeal
# 201 log
# 276 london
# 2076 long
# 331 long term
# 1737 longer
# 207 look
# 210 looked
# 244 looking
# 700 lord
# 647 lorenzen
# 425 lorenzen president
# 351 lorry
# 885 loss
# 762 lost
# 405 low
# 1774 lower
# 193 lower judgment
# 175 ltl
# 185 ltte
# 379 lu
# 269 lublin
# 421 luis
# 419 luis pez
# 279 lung
# 252 lying
# 390 macedonia
# 241 macedonian
# 347 machine
# 280 machine gun
# 237 magazine
# 341 magistrate
# 491 magomed
# 249 mail
# 1563 main
# 437 mainly
# 454 maintain
# 1821 maintained
# 448 maintaining
# 671 maintenance
# 611 major
# 824 majority
# 3028 make
# 1342 making
# 257 male
# 486 malinverni
# 350 malinverni george
# 513 malta
# 194 maltese
# 1193 man
# 414 managed
# 743 management
# 240 manager
# 271 mandate
# 547 mandatory
# 622 manifestly
# 486 manifestly founded
# 1798 manner
# 248 maribor
# 874 mark
# 537 mark villiger
# 396 market
# 704 marriage
# 436 married
# 1272 martan
# 490 martan district
# 358 maruste
# 443 mask
# 249 masked
# 555 mass
# 186 mass medium
# 5800 material
# 279 material condition
# 4317 matter
# 240 mattress
# 540 matyushkin
# 480 matyushkin representative
# 1017 maximum
# 942 mayor
# 279 meal
# 3020 mean
# 1442 meaning
# 355 meaning convention
# 358 meant
# 959 meantime
# 494 meanwhile
# 10056 measure
# 378 measure applied
# 183 measure ensure
# 253 measure restraint
# 585 measured
# 1072 measuring
# 178 measuring cm
# 239 measuring sq
# 308 measuring square
# 362 mechanism
# 13653 medical
# 1052 medical assistance
# 661 medical care
# 500 medical certificate
# 256 medical condition
# 1615 medical examination
# 674 medical expert
# 177 medical institution
# 275 medical practitioner
# 674 medical record
# 957 medical report
# 255 medical staff
# 982 medical treatment
# 313 medical unit
# 639 medication
# 899 medicine
# 228 medicine institute
# 1468 medium
# 721 meet
# 1918 meeting
# 6567 member
# 189 member family
# 247 member illegal
# 197 member parliament
# 832 member state
# 590 membership
# 3120 men
# 354 men camouflage
# 1993 mental
# 344 mental disorder
# 471 mental health
# 242 mental illness
# 276 mentally
# 436 mention
# 2931 mentioned
# 300 mere
# 557 merely
# 5087 merit
# 1389 merit admissibility
# 207 merit complaint
# 934 merit fact
# 1385 met
# 652 metal
# 603 method
# 1790 metre
# 228 migrant
# 904 migration
# 304 mihai
# 274 mihai poalelungi
# 455 mijovi
# 305 milinchuk
# ...
# 2578 residence
# 663 residence permit
# 968 resident
# 299 residential
# 276 residing
# 505 resistance
# 298 resisted
# 1489 resolution
# 210 resolve
# 273 resolved
# 200 resort
# 404 resource
# 363 respected
# 504 respective
# 2095 respectively
# 332 respectively live
# 187 respond
# 243 responded
# 1564 respondent
# 1290 response
# 1873 responsibility
# 2109 responsible
# 463 rest
# 898 restitution
# 195 restoration
# 252 restore
# 239 restored
# 554 restraint
# 525 restricted
# 1525 restriction
# 217 restrictive
# 5682 result
# 214 result use
# 709 resulted
# 656 resulting
# 274 resume
# 1359 resumed
# 345 retained
# 226 retention
# 218 retired
# 451 retirement
# 260 retirement pension
# 303 retrial
# 234 retrospective
# 2473 return
# 284 return child
# 2165 returned
# 254 returning
# 216 reveal
# 516 revealed
# 201 reversed
# 4235 review
# 269 review decision
# 180 review judgment
# 565 reviewed
# 239 reviewing
# 196 revised
# 4030 revision
# 253 revocation
# 292 revoked
# 425 rgvinsson
# 231 ri
# 322 rib
# 243 rifle
# 24929 right
# 455 right alleged
# 201 right child
# 330 right convention
# 188 right decided
# 846 right fifth
# 860 right fourth
# 1592 right freedom
# 4292 right fundamental
# 203 right guaranteed
# 1666 right obligation
# 224 right others
# 1723 right sitting
# 570 right third
# 317 right violation
# 247 right watch
# 255 rijeka
# 329 riot
# 177 riot insurrection
# 521 rise
# 4091 risk
# 254 risk absconding
# 360 risk treatment
# 182 rizvan
# 227 rk
# 827 road
# 1099 robbery
# 719 role
# 606 rom
# 1415 romania
# 189 romania european
# 187 romania judgment
# 187 romania lodged
# 967 romanian
# 177 romanian national
# 183 romanian represented
# 1970 room
# 338 rostov
# 404 rouble
# 229 rouble rub
# 321 round
# 588 rozakis
# 552 rozakis president
# 294 rsan
# 207 rsfsr
# 910 rub
# 285 rubber
# 229 rubber truncheon
# 10287 rule
# 1314 rule admissibility
# 431 rule fact
# 244 rule governing
# 1871 rule rule
# 803 ruled
# 2306 ruling
# 848 run
# 603 running
# 177 ruslan
# 5934 russia
# 916 russia european
# 852 russia judgment
# 218 russia no
# 10905 russian
# 421 russian authority
# 242 russian code
# 252 russian criminal
# 4267 russian federation
# 228 russian military
# 980 russian national
# 178 russian prosecutor
# 845 russian represented
# 311 russian rouble
# 362 safe
# 600 safeguard
# 1446 safety
# 266 safety economic
# 190 safety prevention
# 2771 said
# 455 saj
# 726 salary
# 988 sale
# 305 sample
# 842 sanction
# 771 sanitary
# 179 sanitary condition
# 194 sanitary facility
# 261 santiago
# 261 santiago quesada
# 565 satisfaction
# 548 satisfactory
# 179 satisfactory convincing
# 680 satisfied
# 337 satisfy
# 794 save
# 225 save execution
# 279 save following
# 182 saving
# 922 saw
# 865 say
# 376 saying
# 296 scale
# 1403 scene
# 188 scene incident
# 451 schedule
# 1397 scheduled
# 193 scheduled adjourned
# 450 scheme
# 1544 school
# 185 scientific
# 965 scope
# 185 scrutiny
# 577 se
# 206 sea
# 3227 search
# 218 search activity
# 570 searched
# 305 seat
# 183 secondary
# 307 secondly
# 194 secrecy
# 1086 secret
# 809 secretary
# 1072 section
# 265 sector
# 1251 secure
# 398 secure payment
# 337 secured
# 243 securing
# 176 seeing
# 921 seek
# 825 seeker
# 1769 seeking
# 194 seeking compensation
# 178 seems
# 2297 seen
# 839 seized
# 700 seizure
# 1096 self
# 282 sell
# 218 selling
# 214 senate
# 376 send
# 590 senior
# 294 sense
# 178 sensitive
# 3102 sent
# 198 sent back
# 299 sent letter
# 6565 sentence
# 243 sentence following
# 289 sentence imposed
# 204 sentence imprisonment
# 3060 sentenced
# 199 sentenced life
# 252 sentenced prisoner
# 321 sentenced year
# 378 sentencing
# 1490 separate
# 514 separated
# 310 separately
# 255 separation
# 198 seq
# 907 serbia
# 322 serbian
# 293 sergeant
# 3981 serious
# 379 serious crime
# 357 serious criminal
# 422 serious offence
# 426 seriously
# 376 seriousness
# 324 servant
# 896 serve
# 2727 served
# 1997 service
# 3298 serviceman
# 1302 serving
# 313 serving prison
# 492 serving sentence
# 795 session
# 615 set
# 453 setting
# 303 settled
# 906 settlement
# 1717 seven
# 289 seven year
# 177 seventeen
# 302 seventh
# 208 seventy
# 5136 several
# 632 several occasion
# 479 several time
# 216 several witness
# 964 severe
# 312 severely
# 465 severity
# 516 sex
# 1191 sexual
# 210 sexual abuse
# 621 sh
# 407 shali
# 837 share
# 447 shared
# 285 shareholder
# 338 shchiborshch
# 261 sheet
# 335 ship
# 197 shock
# 298 shooting
# 364 shop
# 758 short
# 489 shortcoming
# 526 shortly
# 673 shot
# 342 shoulder
# 185 shouted
# 220 shouting
# 1357 show
# 910 showed
# 569 shower
# 438 showing
# 730 shown
# 360 sicilianos
# 289 sicilianos erik
# 202 sick
# 895 side
# 359 siewicz
# 329 siewicz ministry
# 1025 sign
# 580 signature
# 1456 signed
# 898 significant
# 356 significantly
# 202 silent
# 182 silvis
# 2407 similar
# 237 similarly
# 210 simple
# 327 simply
# 752 single
# 210 sisak
# 609 sister
# 479 sit
# 882 site
# 4706 sitting
# 3977 sitting chamber
# 540 situated
# 3917 situation
# 3663 six
# 234 six imprisonment
# 457 six month
# 332 six year
# 251 sixteen
# 453 sixth
# 239 sixty
# 266 size
# 1035 sizo
# 189 sjc
# 638 sk
# 277 ski
# 201 ski poland
# 321 skopje
# 305 sleep
# 553 sleeping
# 343 sleeping place
# 397 slovak
# 213 slovak republic
# 564 slovakia
# 500 slovenia
# 252 slovenian
# 703 small
# 4221 social
# 219 social care
# 194 social service
# 390 social welfare
# 215 social worker
# 221 socialist
# 1662 society
# 513 society interest
# 834 sofia
# 194 sofia city
# 480 sold
# 647 soldier
# 432 sole
# 528 solely
# 273 solicitor
# 312 solitary
# 265 solitary confinement
# 196 solution
# 190 somalia
# 481 someone
# 294 something
# 332 sometimes
# 4424 son
# 226 son abduction
# 686 soon
# 179 soon possible
# 2090 sought
# 247 sound
# 947 source
# 287 south
# 217 southern
# 291 soviet
# 833 space
# 188 spain
# 222 speak
# 4450 special
# 570 special operation
# 303 special rapporteur
# 431 specialised
# 1022 specialist
# 295 specially
# 2148 specific
# 537 specifically
# 1364 specified
# 431 specify
# 300 speech
# 209 speedily
# 198 spend
# 683 spent
# 268 sphere
# 635 spielmann
# 340 spielmann sverre
# 180 spite
# 376 split
# 338 spoke
# 211 spoken
# 250 sport
# 366 spouse
# 981 sq
# 1510 square
# 1097 square metre
# 438 sri
# 282 sri lanka
# 182 srji
# 1033 st
# 672 st petersburg
# 183 sta
# 218 stable
# 1747 staff
# 1631 stage
# 296 stamp
# 480 stand
# 1523 standard
# 654 standing
# 183 standpoint
# 272 stanley
# 268 stanley naismith
# 458 start
# 1944 started
# 258 starting
# 3411 state
# 311 state party
# 9959 stated
# 176 stated follows
# 288 stated inter
# 208 stateless
# 1451 stating
# 3667 station
# 219 stationed
# 3053 status
# 245 status criminal
# 746 statute
# 1485 statutory
# 277 statutory limit
# 1336 stay
# 1021 stayed
# 209 staying
# 797 steiner
# 516 steiner khanlar
# 1765 step
# 184 stephen
# 176 stephen phillips
# 2866 still
# 706 still pending
# 346 stipulated
# 221 stipulates
# 183 stock
# 337 stolen
# 229 stomach
# 179 stone
# 243 stood
# 675 stop
# 779 stopped
# 306 storage
# 4265 strasbourg
# 3904 strasbourg judgment
# 330 stress
# 956 stressed
# 306 strict
# 282 strictly
# 946 strike
# 585 strong
# 194 strongly
# 292 struck
# 318 structure
# 325 student
# 235 studied
# 748 study
# 419 sub
# 7880 subject
# 196 subject appeal
# 602 subject condition
# 3935 subject editorial
# 289 subject matter
# 3098 subjected
# 1245 subjected torture
# 479 subjected treatment
# 3916 submission
# 231 submission party
# 1810 submit
# 11779 submitted
# 253 submitted copy
# 312 submitted party
# 204 submitted report
# 187 submitted request
# 177 submitted written
# 331 submitting
# 178 subordinate
# 526 subsection
# 1883 subsequent
# 3211 subsequently
# 399 subsidiary
# 1031 substance
# 563 substantial
# 206 substantiate
# 259 substantiated
# 619 substantive
# 192 substitute
# 284 success
# 184 successful
# 217 successor
# 590 sud
# 199 sud republike
# 263 sued
# 227 suffer
# 1607 suffered
# 1690 suffering
# 2665 sufficient
# 176 sufficient evidence
# 260 sufficient ground
# 225 sufficient reason
# 585 sufficiently
# 278 suggest
# 595 suggested
# 566 suicide
# 349 suitable
# 1162 sum
# 897 summarised
# 335 summarised follows
# 177 summarised judgment
# 790 summary
# 218 summary relevant
# 383 summer
# 219 summon
# 796 summoned
# 762 summons
# 570 superior
# 207 supervised
# 424 supervising
# 214 supervising prosecutor
# 1300 supervision
# 1320 supervisory
# 948 supervisory review
# 183 supplement
# 187 supplementary
# 233 supplied
# 428 supply
# 2178 support
# 177 support allegation
# 757 supported
# 252 supporting
# 10272 supreme
# 994 supreme administrative
# 360 supreme cassation
# 294 supreme decision
# 376 supreme dismissed
# 214 supreme judgment
# 294 supreme justice
# 191 supreme quashed
# 197 supreme rejected
# 273 supreme russia
# 341 supreme russian
# 267 supreme ukraine
# 326 supreme upheld
# 261 surcharge
# 344 surface
# 198 surgeon
# 617 surgery
# 194 surgical
# 224 surrender
# 285 surrounding
# 1016 surveillance
# 2443 suspect
# 441 suspect accused
# 1226 suspected
# 552 suspend
# 2086 suspended
# 200 suspended investigation
# 177 suspended resumed
# 758 suspension
# 2365 suspicion
# 664 suspicion committed
# 1445 sustained
# 237 sustained injury
# 384 sverre
# 384 sverre erik
# 546 sweden
# 212 swedish
# 222 swiss
# 428 switzerland
# 254 symptom
# 339 syria
# 2587 system
# 176 systematic
# 188 szczecin
# 639 table
# 553 tajikistan
# 6146 take
# 684 take account
# 190 take decision
# 286 take measure
# 259 take necessary
# 483 take part
# 635 take place
# 2568 taking
# 771 taking account
# 234 taliban
# 251 talk
# 226 tape
# 192 targeted
# 701 task
# 2991 tax
# 273 tax authority
# 391 tax contribution
# 210 tax surcharge
# 188 taxation
# 255 taxi
# 284 tb
# 239 tbilisi
# 355 teacher
# 487 team
# 582 technical
# 216 technique
# 1355 telephone
# 213 telephone call
# 322 telephone conversation
# 669 television
# 220 tell
# 251 temperature
# 283 temporarily
# 1957 temporary
# 175 temporary asylum
# 823 temporary detention
# 2356 ten
# 695 ten year
# 390 tenancy
# 310 tenant
# 3745 term
# 236 term detention
# 353 term imprisonment
# 416 terminate
# 1176 terminated
# 583 termination
# 478 territorial
# 1312 territory
# 504 terrorism
# 777 terrorist
# 1463 test
# 770 testified
# 322 testify
# 1584 testimony
# 225 testing
# 755 text
# 1095 th
# 425 th bj
# 776 theft
# 180 theory
# 578 therapy
# 561 thereafter
# 512 thereby
# 241 therein
# 617 thereof
# 753 thing
# 205 think
# 5440 third
# 264 third fourth
# 759 third party
# 548 third sitting
# 313 thirteen
# 1039 thirty
# 363 thorough
# 803 though
# 387 thought
# 238 thousand
# 1332 threat
# 791 threatened
# 639 threatening
# 712 throughout
# 195 thrown
# 3739 thus
# 277 thus lasted
# 235 ti
# 236 tie
# 209 tied
# 1757 time
# 198 timely
# 234 timur
# 336 tissue
# 848 title
# 389 tjan
# 388 tjan zupan
# 2269 together
# 1008 toilet
# 2484 told
# 3761 took
# 248 took account
# 218 took part
# 971 took place
# 284 tort
# 4259 torture
# 209 torture cruel
# 1384 torture inhuman
# 443 torture treatment
# 362 tortured
# 1110 total
# 1100 towards
# 3790 town
# 350 town prosecutor
# 374 trace
# 438 trade
# 276 trade union
# 568 traffic
# 575 trafficking
# 181 train
# 626 training
# 716 trajkovska
# 320 trajkovska julia
# 178 trajkovska zdravka
# 582 transaction
# 478 transcript
# 2382 transfer
# 3048 transferred
# 246 transit
# 240 transitional
# 442 transmitted
# 796 transport
# 216 transportation
# 375 transported
# 367 trauma
# 276 traumatic
# 515 travel
# 180 travelled
# 565 treasury
# 240 treat
# 1844 treated
# 261 treated police
# 12832 treatment
# 404 treatment police
# 1527 treatment punishment
# 602 treaty
# 13727 trial
# 2533 trial detention
# 871 trial investigation
# 534 trial reasonable
# 252 trial release
# 2560 tribunal
# 359 tribunal contested
# 316 tribunal established
# 219 tribunal protocol
# 1213 tried
# 263 troop
# 637 true
# 529 truncheon
# 209 trust
# 393 truth
# 329 try
# 343 trying
# 458 tsotsoria
# 1281 tuberculosis
# 365 tulkens
# 325 tulkens president
# 2463 turkey
# 311 turkey european
# 320 turkey judgment
# 310 turkey lodged
# 1149 turkish
# 313 turkish national
# 237 turkish represented
# 287 turkovi
# 207 turkovi dmitry
# 435 turn
# 405 turned
# 182 turning
# 290 tv
# 736 twelve
# 189 twelve year
# 1856 twenty
# 193 twenty five
# 400 twenty four
# 192 twenty year
# 681 twice
# 184 twin
# 13596 two
# 175 two application
# 357 two hour
# 291 two men
# 178 two person
# 359 two police
# 228 two week
# 211 two witness
# 1053 two year
# 1189 type
# 581 uah
# 480 uaz
# 279 uaz vehicle
# 258 uga
# 4040 ukraine
# 477 ukraine european
# 461 ukraine judgment
# 476 ukraine lodged
# 1468 ukrainian
# 478 ukrainian national
# 465 ukrainian represented
# 186 ultimately
# 593 un
# 1506 unable
# 195 unacknowledged
# 312 unauthorised
# 197 unchanged
# 367 unclear
# 377 unconstitutional
# 354 undercover
# 536 undergo
# 217 undergone
# 264 underlying
# 346 understand
# 214 understanding
# 334 understood
# 307 undertake
# 413 undertaken
# 618 undertaking
# 195 undertaking leave
# 601 underwent
# 365 undue
# 262 undue delay
# 444 unfair
# 589 unfounded
# 613 unhcr
# 654 unidentified
# 1120 uniform
# 351 unilateral
# 332 unilateral declaration
# 1101 union
# 3555 unit
# 194 unitary
# 3489 united
# 1656 united kingdom
# 897 united nation
# 705 united state
# 517 university
# 518 unjustified
# 1018 unknown
# 3977 unlawful
# 192 unlawful act
# 276 unlawful action
# 199 unlawful detention
# 186 unlawful violence
# 990 unlawfully
# 239 unlawfulness
# 1296 unless
# 177 unlike
# 264 unnecessary
# 390 unreasonable
# 183 unreasonable length
# 2618 unspecified
# 717 unsubstantiated
# 328 unsuccessful
# 349 unsuccessfully
# 252 untrue
# 5161 upheld
# 458 upheld appeal
# 223 upheld conviction
# 914 upheld decision
# 348 upheld instance
# 947 upheld judgment
# 204 upholding
# 3430 upon
# 243 upon arrival
# 365 upon request
# 330 upper
# 202 ural
# 193 urged
# 497 urgent
# 1030 urus
# 986 urus martan
# 307 usd
# 5432 use
# 741 use force
# 525 use property
# 3728 used
# 177 user
# 1111 using
# 213 ussr
# 182 ustavni
# 226 ustawa
# 304 usually
# 823 uzbek
# 217 uzbek authority
# 1504 uzbekistan
# 700 vaji
# 297 vaji anatoly
# 214 vaji president
# 1038 valid
# 334 validity
# 182 valuation
# 712 van
# 2854 various
# 177 various authority
# 177 various date
# 319 vaz
# 2643 vehicle
# 182 venice
# 589 ventilation
# 177 verbal
# 266 verdict
# 215 verified
# 416 verify
# 1173 version
# 387 version event
# 733 vi
# 282 via
# 227 vice
# 185 vice president
# 220 vicinity
# 4699 victim
# 701 victim status
# 241 victim witness
# 746 video
# 253 video recording
# 405 vienna
# 5825 view
# 307 vii
# 274 viii
# 1339 village
# 591 villiger
# 183 villiger isabelle
# 316 vilnius
# 324 vincent
# 305 vincent de
# 218 violate
# 1877 violated
# 247 violated effective
# 187 violated right
# 176 violating
# 9255 violation
# 451 violation article
# 253 violation committed
# 4258 violation convention
# 389 violation protocol
# 403 violation right
# 2232 violence
# 185 violence order
# 643 violent
# 618 virtue
# 197 visa
# 272 visible
# 2983 visit
# 1085 visited
# 241 visiting
# 262 vladimir
# 527 void
# 277 volgograd
# 243 volume
# 347 voluntarily
# 305 voluntary
# 282 voronezh
# 541 vote
# 257 voter
# 185 voting
# 294 vovd
# 584 vre
# 190 vre mirjana
# 229 vre president
# 466 vu
# 439 vu ini
# 252 vulnerable
# 330 waiting
# 405 walk
# 217 walking
# 584 wall
# 178 wampach
# 177 wampach deputy
# 395 want
# 967 wanted
# 771 war
# 185 war crime
# 551 ward
# 297 warder
# 279 warned
# 441 warning
# 1390 warrant
# 225 warrant issued
# 1167 warsaw
# 180 warsaw district
# 371 watch
# 1289 water
# 3397 way
# 438 way impair
# 215 way supervisory
# 664 weapon
# 538 wearing
# 251 website
# 1334 week
# 191 weekly
# 267 weight
# 873 welfare
# 223 welfare centre
# 1581 went
# 743 westerdiek
# 743 westerdiek registrar
# 229 whenever
# 967 whereabouts
# 655 whereas
# 292 whereby
# 456 whilst
# 282 white
# 894 whole
# 2329 whose
# 314 whose right
# 292 wide
# 208 widespread
# 236 widow
# 1867 wife
# 1203 window
# 327 wing
# 213 winter
# 1155 wish
# 565 wished
# 244 withdraw
# 392 withdrawal
# 342 withdrawn
# 303 withdrew
# 7693 without
# 199 without consent
# 321 without delay
# 179 without giving
# 193 without undue
# 9095 witness
# 240 witness heard
# 242 witness stated
# 445 witnessed
# 377 wo
# 359 wo siewicz
# 199 wojtyczek
# 1345 woman
# 550 word
# 265 worded
# 283 wording
# 3071 work
# 714 worked
# 610 worker
# 1300 working
# 424 world
# 622 wound
# 243 wounded
# 304 wrist
# 655 writ
# 395 writ execution
# 864 writing
# 2978 written
# 193 written observation
# 186 written submission
# 237 wroc
# 266 wrong
# 347 wrongful
# 238 wrongly
# 842 wrote
# 240 ya
# 478 yard
# 180 ye
# 10497 year
# 2045 year imprisonment
# 503 year old
# 275 year six
# 354 yerevan
# 1128 yet
# 644 young
# 320 youth
# 379 yudkivska
# 359 yugoslav
# 313 yugoslav republic
# 263 yugoslavia
# 395 yurt
# 406 za
# 857 zagreb
# 251 zagreb county
# 188 zagreb municipal
# 213 zagrebelsky
# 844 zakon
# 324 zaytsev
# 423 zdravka
# 423 zdravka kalaydjieva
# 297 ziemele
# 188 zmir
# 443 zone
# 441 zupan
# Training the random forest...
# C:\Users\danny\AppData\Local\Enthought\Canopy\User\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\danny\AppData\Local\Enthought\Canopy\User\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# [mean: 0.98192, std: 0.01442, params: {}]

# %%
print test.shape

# Create an empty list and append the clean reviews one by one
num_reviews = len(test["sentences"])
clean_test_reviews = [] 

print "Cleaning and parsing the test set ECHR Cases...\n"
for i in xrange(0,num_reviews):
    if( (i+1) % 100 == 0 ):
        print "Case %d of %d\n" % (i+1, num_reviews)
    clean_review = review_to_words( test["sentences"][i] )
    clean_test_reviews.append( clean_review )
# Out:
# (2348, 9)
# Cleaning and parsing the test set ECHR Cases...
#
# Case 100 of 2348
#
# Case 200 of 2348
#
# Case 300 of 2348
#
# Case 400 of 2348
#
# Case 500 of 2348
#
# Case 600 of 2348
#
# Case 700 of 2348
#
# Case 800 of 2348
#
# Case 900 of 2348
#
# Case 1000 of 2348
#
# Case 1100 of 2348
#
# Case 1200 of 2348
#
# Case 1300 of 2348
#
# Case 1400 of 2348
#
# Case 1500 of 2348
#
# Case 1600 of 2348
#
# Case 1700 of 2348
#
# Case 1800 of 2348
#
# Case 1900 of 2348
#
# Case 2000 of 2348
#
# Case 2100 of 2348
#
# Case 2200 of 2348
#
# Case 2300 of 2348

# %%
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

## Use the random forest to make sentiment label predictions
#result = forest.predict(test_data_features)
#
## Copy the results to a pandas dataframe with an "id" column and
## a "sentiment" column
#output = pd.DataFrame( data={"title":test["title"],"conclusion":test["conclusion"], "AV3_Predict":result} )
#
## Use pandas to write the comma-separated output file
#output.to_csv( "Bag_of_Words_LEMM.csv", index=False, quoting=3, escapechar='\\', sep='^' )
 
LR_result = model_LR.predict_proba(test_data_features)[:,1] 
#LR_output = pd.DataFrame(data={"id":test["id"], "AV3":LR_result}) # Create our dataframe that will be written.
LR_output = pd.DataFrame( data={"title":test["title"],"conclusion":test["conclusion"], "AV3_Predict":LR_result} )
#LR_output.to_csv('Logistic_Reg_Proj2.csv', index=False, quoting=3) # Get the .csv file we will submit to Kaggle.
LR_output.to_csv( "A3004_Bag_of_Words_LEMM_UNIBI_CV.csv", index=False, quoting=3, escapechar='\\', sep='^'  )
